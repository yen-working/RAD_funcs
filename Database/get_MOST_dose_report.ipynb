# %% [markdown]
# # Problem Statement
# Need to list all series that are potential dose reports in MOST database.
#
# # Solution
# 1. Filter series with <5 images
# 2. Filter by study descriptions
# 3. Manually review remaining
# 4. Add data cleaning table to the database

# %% [markdown]
# # Code
# ### 1. Setup: get MOST's database

# %%
import AMBRA_Backups
import pandas as pd

# %%
db_name = 'MOST'
db = AMBRA_Backups.database.Database(db_name)

# %% [markdown]
# ### 2. Get dose reports

# %% [markdown]
# Get all series with <5 instances

# %%
columns = [
   'id_series',
   'number_of_dicoms',
   'series_description',
   'id_study',
   'study_description',
   'study_uid',
   'patient_name'
]

# %%
series = db.run_select_query(
   '''
   SELECT img_series.id AS 'id_series', 
      img_series.number_of_dicoms, 
      img_series.series_description,
      img_series.id_study, 
      studies.study_description, 
      studies.study_uid, 
      patients.patient_name 
   FROM MOST.img_series 
   INNER JOIN studies ON studies.id = img_series.id_study
   INNER JOIN patients ON studies.id_patient = patients.id
   WHERE number_of_dicoms < 5
   '''
)

series_df = pd.DataFrame(columns=columns, data=series)
series_df
# Out:
#       id_series  number_of_dicoms    series_description  id_study  \
# 0            13                 1           Dose_Record         2
# 1            22                 1           Dose_Record         3
# 2            34                 1       Viz_LVO_Results         3
# 3            42                 1           Dose_Record         4
# 4            50                 3  AAHead_Scout_MPR_cor         6
# ...         ...               ...                   ...       ...
# 9579     315512                 1    DummySeriesDesc_13      4823
# 9580     315513                 1    DummySeriesDesc_14      4823
# 9581     315515                 1    DummySeriesDesc_16      4823
# 9582     315516                 1    DummySeriesDesc_17      4823
# 9583     315517                 1    DummySeriesDesc_18      4823
#
#                    study_description  \
# 0               CT_HEAD_WO_FOLLOW_UP
# 1     CT_CTA_HEAD_NECK_W_WO_BASELINE
# 2     CT_CTA_HEAD_NECK_W_WO_BASELINE
# 3                         CT_HEAD_WO
# 4         MRI_BRAIN_WO_UNSCHEDULED_1
# ...                              ...
# 9579                ANGIO_EVT_IMAGES
# 9580                ANGIO_EVT_IMAGES
# 9581                ANGIO_EVT_IMAGES
# 9582                ANGIO_EVT_IMAGES
# 9583                ANGIO_EVT_IMAGES
#
#                                             study_uid patient_name
# 0     2.16.840.1.114444.637556529256860325.1059919336         1186
# 1     2.16.840.1.114444.637556527697070963.1636620793         1186
# 2     2.16.840.1.114444.637556527697070963.1636620793         1186
# 3     2.16.840.1.114444.637556529313565633.1365080542         1186
# 4     2.16.840.1.114444.637472723958126760.2599485960         1128
# ...                                               ...          ...
# 9579     1.2.840.114356.2024.16.112.113.147.19.1480.1         1046
# 9580     1.2.840.114356.2024.16.112.113.147.19.1480.1         1046
# 9581     1.2.840.114356.2024.16.112.113.147.19.1480.1         1046
# 9582     1.2.840.114356.2024.16.112.113.147.19.1480.1         1046
# 9583     1.2.840.114356.2024.16.112.113.147.19.1480.1         1046
#
# [9584 rows x 7 columns]

# %% [markdown]
# Filter series with some variation of 'Dose_Record'

# %%
series_dose_filtered = series_df[series_df['series_description'].str.contains('dose', case=False)]
series_dose_filtered
# Out:
#       id_series  number_of_dicoms series_description  id_study  \
# 0            13                 1        Dose_Record         2
# 1            22                 1        Dose_Record         3
# 3            42                 1        Dose_Record         4
# 76          518                 1        Dose_Report        41
# 78          566                 1        Dose_Report        47
# ...         ...               ...                ...       ...
# 9144     297049                 1        Dose_Record      4781
# 9147     297069                 1        Dose_Record      4783
# 9149     297077                 1        Dose_Record      4784
# 9151     297087                 1        Dose_Record      4785
# 9152     297097                 1        Dose_Record      4786
#
#                    study_description  \
# 0               CT_HEAD_WO_FOLLOW_UP
# 1     CT_CTA_HEAD_NECK_W_WO_BASELINE
# 3                         CT_HEAD_WO
# 76              CT_HEAD_WO_FOLLOW_UP
# 78          CTA_HEAD_NECK_W_BASELINE
# ...                              ...
# 9144            CT_HEAD_WO_FOLLOW_UP
# 9147             CTP_HEAD_W_BASELINE
# 9149             CT_HEAD_WO_BASELINE
# 9151        CTA_HEAD_NECK_W_BASELINE
# 9152                      CT_HEAD_WO
#
#                                               study_uid patient_name
# 0       2.16.840.1.114444.637556529256860325.1059919336         1186
# 1       2.16.840.1.114444.637556527697070963.1636620793         1186
# 3       2.16.840.1.114444.637556529313565633.1365080542         1186
# 76          1.2.840.114350.2.430.2.798268.2.435562870.1         1200
# 78    1.2.840.113619.2.182.1080861873190.1620672412....         1196
# ...                                                 ...          ...
# 9144  1.2.840.113619.2.340.3.3356099742.545.16736785...         1491
# 9147           2.16.840.1.113786.1.52.17.945033817.3545         1491
# 9149           2.16.840.1.113786.1.52.17.945033815.3543         1491
# 9151           2.16.840.1.113786.1.52.17.945033816.3544         1491
# 9152  1.3.6.1.4.1.34692.1299329988276728633034773285...         1491
#
# [582 rows x 7 columns]
