# %% [markdown]
# # Problem Statement
#
# Functionalities to backup REDCap data in the database is constantly being maintained and updated. There needs to be a way to quickly verify that the data in the backup database is the same as the data on REDCap.
#
# This comparison goes both ways--data found in REDCap should be in the database, and data found in the database should be on REDCap.
#
# # Solution
#
# This notebook pulls data from REDCap and the database and do cross checking. Then, differences (if any) are exported to an excel file.

# %% [markdown]
# # Code
# ### 1. Setup: get project's records and database's data

# %%
import AMBRA_Backups
import pandas as pd
import logging
from datetime import datetime
from redcap import Project
from AMBRA_Backups.Database.database import Database
from AMBRA_Backups.redcap_funcs import get_project_instru_field_map
logger = logging.getLogger(__name__)

# %%
project_name = 'TESTED DC'
db_name = 'TESTED'

# %% [markdown]
# Get project's data

# %%
project = AMBRA_Backups.redcap_funcs.get_redcap_project(project_name)

# %%
def get_project_records(project: Project):
    '''Get records from REDCap project'''
    project_records = project.export_records(format_type='df')
    project_records.reset_index(inplace=True)
    project_records.to_excel(f'{project_name}_redcap_original.xlsx')
    return project_records

# %%
def get_field_instru_map(instru_field_map: dict):
    '''
    Get lookup table for every variable in redcap project.
    '''
    field_instru_map = dict()
    for instru in instru_field_map:
        for field in instru_field_map[instru]:
            field_instru_map[field] = instru

    return field_instru_map

# %%
def process_project_records(project_records: pd.DataFrame, field_instru_map: dict):
    '''
    1. Turn data from wide to long for easier comparison with database data
    2. Rename, sort based on patient_name
    3. Convert data types for easier comparisons
    '''
    # Wide to long
    project_records = pd.melt(project_records, id_vars=['record_id', 'redcap_repeat_instrument', 'redcap_repeat_instance'])

    # Rename for less confusion when comparing
    project_records.rename(
        columns={
            'record_id': 'patient_name',
            'redcap_repeat_instrument': 'crf_name',
            'redcap_repeat_instance': 'instance',
            'variable': 'redcap_variable',
        }, inplace=True
    )

    # Filter out 'residual rows'
    # Residual rows are defined as rows that have a repeating instrument paired with a redcap variable not belonging to it.
    # These rows do not contain the actual value of said variable.
    # TODO: figure out how to actual do this
    project_records = project_records[
        pd.notna(project_records['crf_name']) &
        project_records['redcap_variable'] == 
    ]

    # Sort
    project_records.sort_values(by='patient_name', inplace=True)

    # Data type conversion
    # object -> str
    project_records['value'] = project_records['value'].astype("string")
    project_records['redcap_variable'] = project_records['redcap_variable'].astype("string")
    project_records['crf_name'] = project_records['crf_name'].astype("string")
    project_records['patient_name'] = project_records['patient_name'].astype("string")
    
    project_records.to_excel(f'{project_name}_redcap.xlsx')

    return project_records

# %%
instru_field_map = get_project_instru_field_map(project)
field_instru_map = get_field_instru_map(instru_field_map)

# %%
project_records = get_project_records(project)
project_records
# Out:
#      record_id redcap_repeat_instrument  redcap_repeat_instance  q1001  \
# 0        11001                      NaN                     NaN    1.0
# 1        11001                 followup                     1.0    NaN
# 2        11002                      NaN                     NaN    1.0
# 3        11002                 followup                     1.0    NaN
# 4        11003                      NaN                     NaN    1.0
# ..         ...                      ...                     ...    ...
# 223      23005                      NaN                     NaN    1.0
# 224      23005                 followup                     1.0    NaN
# 225      23006                      NaN                     NaN    1.0
# 226      23007                      NaN                     NaN    1.0
# 227      23007                 followup                     1.0    NaN
#
#      q1002___1  q1002___2  q1002___3  q1002___4  q1003       q1004  ...  \
# 0          1.0        1.0        0.0        0.0    NaN  2024-02-14  ...
# 1          NaN        NaN        NaN        NaN    NaN         NaN  ...
# 2          1.0        1.0        0.0        0.0    NaN  2024-02-24  ...
# 3          NaN        NaN        NaN        NaN    NaN         NaN  ...
# 4          1.0        1.0        0.0        0.0    NaN  2024-03-26  ...
# ..         ...        ...        ...        ...    ...         ...  ...
# 223        1.0        1.0        1.0        0.0    NaN  2024-11-10  ...
# 224        NaN        NaN        NaN        NaN    NaN         NaN  ...
# 225        1.0        1.0        1.0        0.0    NaN  2024-12-11  ...
# 226        1.0        1.0        0.0        0.0    NaN  2025-01-07  ...
# 227        NaN        NaN        NaN        NaN    NaN         NaN  ...
#
#     f_u_cr_sign                                           comments  \
# 0           NaN                                                NaN
# 1           MGS                                                NaN
# 2           NaN                                                NaN
# 3           MGS  signature added by VJK. Signature corrected fr...
# 4           NaN                                                NaN
# ..          ...                                                ...
# 223         NaN                                                NaN
# 224         MGS                                                NaN
# 225         NaN                                                NaN
# 226         NaN                                                NaN
# 227         NaN                                                NaN
#
#      f_u_status                                       f_u_comments  f_u_init  \
# 0           NaN                                                NaN       NaN
# 1           4.0  Unchecked CTA in Scan Type because a CTA does ...       JJJ
# 2           NaN                                                NaN       NaN
# 3           4.0  "Signature of Central Reader" unanswered; JJJ....       JJJ
# 4           NaN                                                NaN       NaN
# ..          ...                                                ...       ...
# 223         NaN                                                NaN       NaN
# 224         4.0                                                NaN       JJJ
# 225         NaN                                                NaN       NaN
# 226         NaN                                                NaN       NaN
# 227         1.0             Corrected timestamp of follow-up. JJJ.       NaN
#
#      followup_complete  ambra_img_url  is_test  is_phantom  \
# 0                  NaN            NaN      NaN         NaN
# 1                  2.0            NaN      NaN         NaN
# 2                  NaN            NaN      NaN         NaN
# 3                  2.0            NaN      NaN         NaN
# 4                  NaN            NaN      NaN         NaN
# ..                 ...            ...      ...         ...
# 223                NaN            NaN      NaN         NaN
# 224                2.0            NaN      NaN         NaN
# 225                NaN            NaN      NaN         NaN
# 226                NaN            NaN      NaN         NaN
# 227                0.0            NaN      NaN         NaN
#
#      lab_use_only_complete
# 0                      0.0
# 1                      NaN
# 2                      0.0
# 3                      NaN
# 4                      0.0
# ..                     ...
# 223                    0.0
# 224                    NaN
# 225                    0.0
# 226                    0.0
# 227                    NaN
#
# [228 rows x 1853 columns]

# %%
project_records = process_project_records(project_records)
project_records
# Out:
#        patient_name  crf_name  instance        redcap_variable value
# 0             11001      <NA>       NaN                  q1001   1.0
# 10032         11001      <NA>       NaN  q1012_w_laca_lpca___1   0.0
# 120157        11001  followup       1.0  l_paraclinoid_ica___1  <NA>
# 262201        11001  followup       1.0    l_car_bif_evt_8___1  <NA>
# 262200        11001      <NA>       NaN    l_car_bif_evt_8___1   0.0
# ...             ...       ...       ...                    ...   ...
# 278158        23007      <NA>       NaN       r_aica_evt_9___1   0.0
# 277931        23007  followup       1.0   r_dist_pca_evt_9___1  <NA>
# 277930        23007      <NA>       NaN   r_dist_pca_evt_9___1   0.0
# 277702        23007      <NA>       NaN         r_p3_evt_9___1   0.0
# 421799        23007  followup       1.0  lab_use_only_complete  <NA>
#
# [421800 rows x 5 columns]

# %% [markdown]
# Get database data

# %%
db = Database(db_name)

# %%
def get_database_records(db: Database):
    '''Get records from database'''
    records = db.run_select_query(
        f"""
        SELECT * FROM {db_name}.CRF_Data_RedCap 
        INNER JOIN {db_name}.CRF_RedCap 
            ON {db_name}.CRF_Data_RedCap.id_crf = {db_name}.CRF_RedCap.id
        INNER JOIN {db_name}.patients
            ON {db_name}.CRF_RedCap.id_patient = {db_name}.patients.id
        """,
        column_names=True
    )
    records = pd.DataFrame.from_records(records)
    return records

# %%
def process_database_records(db_records: pd.DataFrame):
    '''
    1. Drop irrelevant columns and sort based on patient_name
    2. Convert data types for easier comparisons
    '''
    
    # Drop & Sort
    db_records.reset_index(inplace=True)
    db_records.drop(labels=['index','id', 'id_crf', 'record_created', 'is_phantom', 'record_updated', 'id_patient', 'patient_id', 'is_phantom'], inplace=True, axis=1)
    db_records.sort_values(by='patient_name', inplace=True)

    # Data type conversion
    # Before converting
    print(db_records.info(verbose=True))
    # object -> str
    db_records['value'] = db_records['value'].astype("string")
    db_records['redcap_variable'] = db_records['redcap_variable'].astype("string")
    db_records['crf_name'] = db_records['crf_name'].astype("string")
    db_records['patient_name'] = db_records['patient_name'].astype("string")

    # After converting
    print(db_records.info(verbose=True))
    db_records.to_excel(f'{db_name}_database.xlsx')

    return db_records

# %%
db_records = get_database_records(db)
db_records = process_database_records(db_records)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186417 entries, 97013 to 3978
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   value            186417 non-null  object
#  1   redcap_variable  186417 non-null  object
#  2   crf_name         186417 non-null  object
#  3   instance         12707 non-null   float64
#  4   verified         186417 non-null  int64
#  5   deleted          186417 non-null  int64
#  6   patient_name     186417 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 186417 entries, 97013 to 3978
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   value            186417 non-null  string
#  1   redcap_variable  186417 non-null  string
#  2   crf_name         186417 non-null  string
#  3   instance         12707 non-null   float64
#  4   verified         186417 non-null  int64
#  5   deleted          186417 non-null  int64
#  6   patient_name     186417 non-null  string
# dtypes: float64(1), int64(2), string(4)
# memory usage: 11.4 MB
# None

# %%
db_records
# Out:
#       value         redcap_variable crf_name  instance  verified  deleted  \
# 97013     0           r_p3_evt_3(1)      evt       NaN         1        0
# 96245     0    l_distal_a2_evt_8(1)      evt       NaN         1        0
# 96246     0    l_distal_a2_evt_9(1)      evt       NaN         1        0
# 96247     0      l_distal_a2_evt(1)      evt       NaN         1        0
# 96248     0  l_distal_aca_evt_10(1)      evt       NaN         1        0
# ...     ...                     ...      ...       ...       ...      ...
# 4029      0                q1010(3)       ct       NaN         0        1
# 4028      0                q1010(2)       ct       NaN         0        1
# 4027      0                q1010(1)       ct       NaN         0        1
# 4034      0         q1012_l_heub(1)       ct       NaN         0        1
# 3978      0            l_aica_ct(1)       ct       NaN         0        1
#
#       patient_name
# 97013        11001
# 96245        11001
# 96246        11001
# 96247        11001
# 96248        11001
# ...            ...
# 4029         90003
# 4028         90003
# 4027         90003
# 4034         90003
# 3978         90003
#
# [186417 rows x 7 columns]

# %% [markdown]
# ### 2. Comparison

# %% [markdown]
# Map `project_records` to `db_records`.

# %%
def check_checkbox_redcap_var(redcap_variable: str):
    '''
    Check if `redcap_variable` is a checkbox variable.
    A checkbox variable would have two underscores before its final part.
    Example:

    checkbox_variable___1
    Two conditions:
    1. '___' is in redcap_variable
    2. '___' is the last underscore occurrence in redcap_variable
    '''
    if ('__' in redcap_variable) and (redcap_variable.rindex('_') == (redcap_variable.rindex('___') + 2)):
        return True
    return False

# %%
def extract_variable(redcap_variable: str):
    '''
    Extract the original variable if it is a multichoice variable.
    '''
    if check_checkbox_redcap_var(redcap_variable):
        before_choice = redcap_variable[:(redcap_variable.rindex('___'))]
        return before_choice
    return redcap_variable

# %%
def check_filled_instrument(record, crf_name: str, project_records: pd.DataFrame):
    '''
    Check if a particular instrument has been filled out for a record in project_records.
    '''
    instrument_complete = f'{crf_name}_complete'
    filled_out = project_records[
        (project_records['crf_name'] == crf_name) & 
        (project_records['redcap_variable'] == instrument_complete) &
        (pd.notna(project_records['value']))
    ]

    if len(filled_out) > 0:
        return True
    return False

# %%
def get_unfilled_instru(record, project_records: pd.DataFrame, field_instru_map: dict):
    '''Get set of instruments that are unfilled of a specific record'''
    unfilled_instru = set()
    filled_instru = set()
    print(f'''
        Record:     {record}
        ''')

    variables = project_records['redcap_variable'].unique()

    for variable in variables:
        instru = field_instru_map[variable]

        if (instru in unfilled_instru ) or (instru in filled_instru):
            continue
        
    # for instru in instru_field_map:
    #     filled = project_records[
    #         (project_records['patient_name'] == record) &
    #         (project_records['crf_name'] == instru) 
    #         # (~project_records[pd.isna(f'{instru}_complete')])
    #     ]
    #     print(f'instru: {instru}')
    #     print(f'''filled:
    #           {filled} 
    #           ''')
    #     if len(filled) == 0:
    #         instru = instru['crf_name'].iloc[0]
    #         unfilled_instru.add(instru)

    return unfilled_instru

# %%
def get_record_unfilled_instru_map(project_records: pd.DataFrame, instru_field_map:dict):
    '''Get a map of {record: set of unfilled instruments}'''

    record_unfilled_instru_map = dict()
    records = project_records['patient_name'].unique()

    for record in records:
        unfilled_instru = get_unfilled_instru(record, project_records, instru_field_map)
        record_unfilled_instru_map[record] = unfilled_instru

    return record_unfilled_instru_map

# %%
record_unfilled_instru_map = get_record_unfilled_instru_map(project_records, instru_field_map)
# Out:
#         Record:     11001
#
# instru: ct
# filled:
#               Empty DataFrame
# Columns: [patient_name, crf_name, instance, redcap_variable, value]
# Index: []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 3
#       1 instru_field_map = get_project_instru_field_map(project)
#       2 field_instru_map = get_field_instru_map(instru_field_map)
# ----> 3 record_unfilled_instru_map = get_record_unfilled_instru_map(project_records, instru_field_map)
#
# Cell In[134], line 8, in get_record_unfilled_instru_map(project_records, instru_field_map)
#       5 records = project_records['patient_name'].unique()
#       7 for record in records:
# ----> 8     unfilled_instru = get_unfilled_instru(record, project_records, instru_field_map)
#       9     record_unfilled_instru_map[record] = unfilled_instru
#      11 return record_unfilled_instru_map
#
# Cell In[152], line 19, in get_unfilled_instru(record, project_records, instru_field_map)
#      15     print(f'''filled:
#      16           {filled}
#      17           ''')
#      18     if len(filled) == 0:
# ---> 19         instru = instru['crf_name'].iloc[0]
#      20         unfilled_instru.add(instru)
#      22 return unfilled_instru
#
# TypeError: string indices must be integers, not 'str'

# %%
print(f'instru field map: {instru_field_map}')
print(f'field instru map: {field_instru_map}')
print(f'record unfilled instru map: {record_unfilled_instru_map}')
# Out:
# {'ct': ['q1001',
#   'q1002',
#   'q1003',
#   'q1004',
#   'q1005',
#   'q1006',
#   'q1007',
#   'q1008',
#   'q7001',
#   'q7002',
#   'q7003',
#   'q1009',
#   'q1010',
#   'q1011',
#   'q1012_table',
#   'q1012_raca',
#   'q1012_r_heub',
#   'q1012_rmca',
#   'q1012_r_len_str',
#   'q1012_r_ant_ch_art',
#   'q1012_r_pca',
#   'q1012_r_post_cer_art',
#   'q1012_w_raca_rmca',
#   'q1012_w_rmca_rpca',
#   'q1012_w_raca_rpca',
#   'q1012_laca',
#   'q1012_l_heub',
#   'q1012_l_mca',
#   'q1012_l_len_str',
#   'q1012_l_ant_ch_art',
#   'q1012_l_pca',
#   'q1012_l_post_cer_art',
#   'q1012_w_laca_lmca',
#   'q1012_w_lmca_lpca',
#   'q1012_w_laca_lpca',
#   'q1013_table',
#   'q1013_r_pica',
#   'q1013_r_aica',
#   'q1013_r_sca',
#   'q1013_r_pca_ct',
#   'q1013_bas_per',
#   'q1013_l_pica',
#   'q1013_l_aica',
#   'q1013_l_sca',
#   'q1013_l_pca_ct',
#   'q1015',
#   'q1016',
#   'hyperdense_table',
#   'q1017_r_car_term',
#   'q1017_r_mca',
#   'q1017_bas',
#   'q1017_r_aca_iv',
#   'q1017_r_pca_iv',
#   'q1017_other_box',
#   'q1017_other',
#   'q1017_l_car_term',
#   'q1017_l_mca',
#   'q1017_l_aca_iv',
#   'q1017_l_pca_iv',
#   'aspects_table',
#   'q1019_cau',
#   'q1020_len_nuc',
#   'q1021_ins_rib',
#   'q1022_int_cap',
#   'q1023_m1',
#   'q1024_m2',
#   'q1025_m3',
#   'q1026_m4',
#   'q1027_m5',
#   'q1028_m6',
#   'q1029_total',
#   'q1030',
#   'q1031',
#   'q1032',
#   'q1033',
#   'q1056',
#   'q1034',
#   'q1035',
#   'q1036',
#   'q1037',
#   'q1038',
#   'q1039',
#   'q1040',
#   'q1041',
#   'q1042',
#   'q1043',
#   'q1044',
#   'q1045',
#   'q1046',
#   'q1047',
#   'q1048',
#   'q1049',
#   'q1050',
#   'q1051',
#   'q1052',
#   'q1053',
#   'q1054',
#   'q1055',
#   'q1057',
#   'q1058',
#   'q1059',
#   'q1060',
#   'pil_col_table',
#   'q1061',
#   'q1062',
#   'q1063',
#   'placeholder',
#   'r_com_car_ct',
#   'r_car_bif_ct',
#   'r_dist_ext_ica_ct',
#   'r_petrous_ica_ct',
#   'r_cavernous_ica_ct',
#   'r_paraclinoid_ica_ct',
#   'r_ica_terminous_ct',
#   'r_prox_m1_ct',
#   'r_distal_m1_ct',
#   'r_prox_dom_m2_ct',
#   'r_prox_codom_m2_ct',
#   'r_prox_nondom_m2_ct',
#   'r_ant_temp_art_ct',
#   'r_dist_dom_m2_ct',
#   'r_dist_codom_m2_ct',
#   'r_dist_nondom_m2_ct',
#   'r_m3_ct',
#   'r_dist_m3_ct',
#   'r_prox_a1_ct',
#   'r_distal_a1_ct',
#   'r_prox_a2_ct',
#   'r_distal_a2_ct',
#   'r_pericallosal_ct',
#   'r_callosomarginal_ct',
#   'r_distal_aca_ct',
#   'r_vert_art_ct',
#   'r_vert_bas_jun_ct',
#   'r_mid_bas_ct',
#   'r_top_bas_ct',
#   'r_p1_ct',
#   'r_p2_ct',
#   'r_p3_ct',
#   'r_dist_pca_ct',
#   'r_aica_ct',
#   'r_pica_ct',
#   'r_sca_ct',
#   'other_ct',
#   'l_com_car_ct',
#   'l_car_bif_ct',
#   'l_dist_ext_ica_ct',
#   'l_petrous_ica_ct',
#   'l_cavernous_ica_ct',
#   'l_paraclinoid_ica_ct',
#   'l_ica_terminous_ct',
#   'l_prox_m1_ct',
#   'l_distal_m1_ct',
#   'l_prox_dom_m2_ct',
#   'l_prox_codom_m2_ct',
#   'l_prox_nondom_m2_ct',
#   'l_ant_temp_art_ct',
#   'l_dist_dom_m2_ct',
#   'l_dist_codom_m2_ct',
#   'l_dist_nondom_m2_ct',
#   'l_m3_ct',
#   'l_prox_a1_ct',
#   'l_dist_m3_ct',
#   'l_distal_a1_ct',
#   'l_prox_a2_ct',
#   'l_distal_a2_ct',
#   'l_pericallosal_ct',
#   'l_callosomarginal_ct',
#   'l_distal_aca_ct',
#   'l_vert_art_ct',
#   'l_vert_bas_jun_ct',
#   'l_mid_bas_ct',
#   'l_top_bas_ct',
#   'l_p1_ct',
#   'l_p2_ct',
#   'l_p3_ct',
#   'l_dist_pca_ct',
#   'l_aica_ct',
#   'l_pica_ct',
#   'l_sca_ct',
#   'q1065',
#   'q1087',
#   'q1089',
#   'q1091',
#   'q1093',
#   'q1094',
#   'q1095',
#   'q1097',
#   'q1098',
#   'q1099',
#   'q1100',
#   'ct_status',
#   'ct_comments',
#   'ct_init',
#   'ct_complete'],
#  'mr': ['q2001',
#   'q2002',
#   'q2003',
#   'q2004',
#   'q2005',
#   'q2006',
#   'q2007',
#   'q2008',
#   'q8001',
#   'q8002',
#   'q8003',
#   'q2010',
#   'q2011',
#   'q2012',
#   'q2013',
#   'q2013_raca',
#   'q2013_r_heub',
#   'q2013_rmca',
#   'q2013_r_len_str',
#   'q2013_r_ant_ch_art',
#   'q2013_r_pca',
#   'q2013_w_raca_rmca',
#   'q2013_w_rmca_rpca',
#   'q2013_w_raca_rpca',
#   'q2013_laca',
#   'q2013_l_heub',
#   'q2013_l_mca',
#   'q2013_l_len_str',
#   'q2013_l_ant_ch_art',
#   'q2013_l_pca',
#   'q2013_w_laca_lmca',
#   'q2013_w_lmca_lpca',
#   'q2013_w_laca_lpca',
#   'q2014_table',
#   'q2014_r_pica',
#   'q2014_r_aica',
#   'q2014_r_sca',
#   'q2014_r_pca',
#   'q2014_bas_per',
#   'q2014_l_pica',
#   'q2014_l_aica',
#   'q2014_l_sca',
#   'q2014_l_pca',
#   'q2015',
#   'q2016',
#   'q2017',
#   'q2018a',
#   'q2019a',
#   'q2019_r_par',
#   'q2019_l_par',
#   'q2019_r_occ',
#   'q2019_l_occ',
#   'q2019_r_tem',
#   'q2019_l_tem',
#   'q2019_r_fron',
#   'q2019_l_fron',
#   'q2019_r_ins',
#   'q2019_l_ins',
#   'q2019_r_cau_nuc',
#   'q2019_l_cau_nuc',
#   'q2019_r_put',
#   'q2019_l_put',
#   'q2019_r_cor',
#   'q2019_l_cor',
#   'q2019_r_int_cap',
#   'q2019_l_int_cap',
#   'q2019_r_thal',
#   'q2019_l_thal',
#   'q2019_r_cere',
#   'q2019_l_cere',
#   'q2019_r_pon',
#   'q2019_l_pon',
#   'q2019_r_midb',
#   'q2019_l_midb',
#   'q2019_r_med',
#   'q2019_l_med',
#   'q2019_r_oth_deep',
#   'q2019_l_oth_deep',
#   'q2019_r_mca_aca',
#   'q2019_l_mca_aca',
#   'q2019_r_pca_mca',
#   'q2019_l_pca_mca',
#   'q2019_r_pca_aca',
#   'q2019_l_pca_aca',
#   'q2019_r_scatt',
#   'q2019_l_scatt',
#   'q2019_oth',
#   'q2020',
#   'q2020_cau',
#   'q2021_len_nuc',
#   'q2022_ins_rib',
#   'q2023_int_cap',
#   'q2024_m1',
#   'q2025_m2',
#   'q2026_m3',
#   'q2027_m4',
#   'q2028_m5',
#   'q2029_m6',
#   'q2030_total',
#   'q2018',
#   'q2029_mr',
#   'q2030_mr',
#   'q2031_mr',
#   'q2031_r_car_term_mr',
#   'q2031_r_mca_mr',
#   'q2031_r_aca_mr',
#   'q2031_r_pca_mr',
#   'q2031_l_car_term_mr',
#   'q2031_l_mca_mr',
#   'q2031_l_aca_mr',
#   'q2031_l_pca_mr',
#   'q2031_bas_mr',
#   'q2031_oth_box',
#   'q2032_mr',
#   'q2033_mr',
#   'q2034_mr',
#   'q1035_mr',
#   'q1036_mr',
#   'q1037_mr',
#   'q1038_mr',
#   'q1039_mr',
#   'q1040_mr',
#   'q1041_mr',
#   'microbleeds_table1',
#   'q2045_d_r',
#   'q2045_d_l',
#   'q2045_p_r',
#   'q2045_p_l',
#   'q2046_d_r',
#   'q2046_d_l',
#   'q2046_p_r',
#   'q2046_p_l',
#   'q2047',
#   'q2048_d_r',
#   'q2048_d_l',
#   'q2048_p_r',
#   'q2048_p_l',
#   'q2049_d_r',
#   'q2049_d_l',
#   'q2049_p_r',
#   'q2049_p_l',
#   'q2050_d_r',
#   'q2050_d_l',
#   'q2050_p_r',
#   'q2050_p_l',
#   'q2051_d_r',
#   'q2051_d_l',
#   'q2051_p_r',
#   'q2051_p_l',
#   'q2052_d_r',
#   'q2052_d_l',
#   'q2052_p_r',
#   'q2052_p_l',
#   'q2053_d_r',
#   'q2053_d_l',
#   'q2053_p_r',
#   'q2053_p_l',
#   'q2054',
#   'q2055_d_r',
#   'q2055_d_l',
#   'q2055_p_r',
#   'q2055_p_l',
#   'q2056_d_r',
#   'q2056_d_l',
#   'q2056_p_r',
#   'q2056_p_l',
#   'q2057_d_r',
#   'q2057_d_l',
#   'q2057_p_r',
#   'q2057_p_l',
#   'q2058_d_r',
#   'q2058_d_l',
#   'q2058_p_r',
#   'q2058_p_l',
#   'q2059_d_r',
#   'q2059_d_l',
#   'q2059_p_r',
#   'q2059_p_l',
#   'q2060_l_t',
#   'q2061_overall_t',
#   'q2125',
#   'q2126',
#   'q2127',
#   'q2062_mr',
#   'q2063_mr',
#   'q2064_mr',
#   'q2065_mr',
#   'q2062',
#   'q2062_table',
#   'q2063',
#   'q2064',
#   'q2065',
#   'q2066',
#   'q2067',
#   'q2068',
#   'q2068_table',
#   'q2069',
#   'q2070',
#   'q2071',
#   'q2072',
#   'q2073',
#   'q2074',
#   'q2074_table',
#   'q2075',
#   'q2076',
#   'q2077',
#   'q2078',
#   'q2079',
#   'q2080',
#   'q2080_table',
#   'q2081',
#   'q2082',
#   'q2083',
#   'q2084',
#   'q2085',
#   'q2086',
#   'q2087',
#   'q2088',
#   'q2089',
#   'q2090',
#   'q2091',
#   'q2092',
#   'q2093',
#   'q2094',
#   'q2095',
#   'q2096_table',
#   'q2096',
#   'q2097',
#   'q2098',
#   'q2099',
#   'q2100',
#   'pen_table',
#   'q2101',
#   'q2102',
#   'q2103',
#   'q2104',
#   'q2105',
#   'q2106',
#   'q2107',
#   'q2108',
#   'q2109',
#   'q2110',
#   'q2111',
#   'q2112_table',
#   'q2112',
#   'q2113',
#   'q2114',
#   'evt_table',
#   'r_com_car_mr',
#   'r_car_bif_mr',
#   'r_dist_ext_ica_mr',
#   'r_petrous_ica',
#   'r_cavernous_ica',
#   'r_paraclinoid_ica',
#   'r_ica_terminous',
#   'r_prox_m1',
#   'r_distal_m1',
#   'r_prox_dom_m2',
#   'r_prox_codom_m2',
#   'r_prox_nondom_m2',
#   'r_ant_temp_art',
#   'r_dist_dom_m2',
#   'r_dist_codom_m2',
#   'r_dist_nondom_m2',
#   'r_m3',
#   'r_dist_m3',
#   'r_prox_a1',
#   'r_distal_a1',
#   'r_prox_a2',
#   'r_distal_a2',
#   'r_pericallosal',
#   'r_callosomarginal',
#   'r_distal_aca',
#   'r_vert_art',
#   'r_vert_bas_jun',
#   'r_mid_bas',
#   'r_top_bas',
#   'r_p1',
#   'r_p2',
#   'r_p3',
#   'r_dist_pca',
#   'r_aica_mr',
#   'r_pica_mr',
#   'r_sca_mr',
#   'other',
#   'l_com_car_mr',
#   'l_car_bif_mr',
#   'l_dist_ext_ica_mr',
#   'l_petrous_ica',
#   'l_cavernous_ica',
#   'l_paraclinoid_ica',
#   'l_ica_terminous',
#   'l_prox_m1',
#   'l_distal_m1',
#   'l_prox_dom_m2',
#   'l_prox_codom_m2',
#   'l_prox_nondom_m2',
#   'l_ant_temp_art',
#   'l_dist_dom_m2',
#   'l_dist_codom_m2',
#   'l_dist_nondom_m2',
#   'l_m3',
#   'l_dist_m3',
#   'l_prox_a1',
#   'l_distal_a1',
#   'l_prox_a2',
#   'l_distal_a2',
#   'l_pericallosal',
#   'l_callosomarginal',
#   'l_distal_aca',
#   'l_vert_art',
#   'l_vert_bas_jun',
#   'l_mid_bas',
#   'l_top_bas',
#   'l_p1',
#   'l_p2',
#   'l_p3',
#   'l_dist_pca',
#   'l_aica_mr',
#   'l_pica_mr',
#   'l_sca_mr',
#   'q2115_oth',
#   'q2117',
#   'q2119',
#   'q2121',
#   'q2122',
#   'q2124',
#   'q2129',
#   'q2131',
#   'mr_status',
#   'mri_comments',
#   'mr_init',
#   'mr_complete'],
#  'evt': ['q3002',
#   'q3003',
#   'q3005',
#   'q3006',
#   'q3007',
#   'q3008',
#   'q3009',
#   'q3010',
#   'q3011',
#   'prox_q3012',
#   'q3012_first_cer_evt_table',
#   'r_com_car_evt',
#   'r_car_bif_evt',
#   'r_dist_ext_ica_evt',
#   'r_petrous_ica_evt',
#   'r_cavernous_ica_evt',
#   'r_paraclinoid_ica_evt',
#   'r_ica_terminous_evt',
#   'r_prox_m1_evt',
#   'r_distal_m1_evt',
#   'r_prox_dom_m2_evt',
#   'r_prox_codom_m2_evt',
#   'r_prox_nondom_m2_evt',
#   'r_ant_temp_art_evt',
#   'r_dist_dom_m2_evt',
#   'r_dist_codom_m2_evt',
#   'r_dist_nondom_m2_evt',
#   'r_m3_evt',
#   'r_dist_m3_evt',
#   'r_prox_a1_evt',
#   'r_distal_a1_evt',
#   'r_prox_a2_evt',
#   'r_distal_a2_evt',
#   'r_pericallosal_evt',
#   'r_callosomarginal_evt',
#   'r_distal_aca_evt',
#   'r_vert_art_evt',
#   'r_vert_bas_jun_evt',
#   'r_mid_bas_evt',
#   'r_top_bas_evt',
#   'r_p1_evt',
#   'r_p2_evt',
#   'r_p3_evt',
#   'r_dist_pca_evt',
#   'r_aica_evt',
#   'r_pica_evt',
#   'r_sca_evt',
#   'other_evt',
#   'l_com_car_evt',
#   'l_car_bif_evt',
#   'l_dist_ext_ica_evt',
#   'l_petrous_ica_evt',
#   'l_cavernous_ica_evt',
#   'l_paraclinoid_ica_evt',
#   'l_ica_terminous_evt',
#   'l_prox_m1_evt',
#   'l_distal_m1_evt',
#   'l_prox_dom_m2_evt',
#   'l_prox_codom_m2_evt',
#   'l_prox_nondom_m2_evt',
#   'l_ant_temp_art_evt',
#   'l_dist_dom_m2_evt',
#   'l_dist_codom_m2_evt',
#   'l_dist_nondom_m2_evt',
#   'l_m3_evt',
#   'l_dist_m3_evt',
#   'l_prox_a1_evt',
#   'l_distal_a1_evt',
#   'l_prox_a2_evt',
#   'l_distal_a2_evt',
#   'l_pericallosal_evt',
#   'l_callosomarginal_evt',
#   'l_distal_aca_evt',
#   'l_vert_art_evt',
#   'l_vert_bas_jun_evt',
#   'l_mid_bas_evt',
#   'l_top_bas_evt',
#   'l_p1_evt',
#   'l_p2_evt',
#   'l_p3_evt',
#   'l_dist_pca_evt',
#   'l_aica_evt',
#   'l_pica_evt',
#   'l_sca_evt',
#   'q3013',
#   'q3014',
#   'first_cer_bleed_table',
#   'r_com_car_evt_2',
#   'r_car_bif_evt_2',
#   'r_dist_ext_ica_evt_2',
#   'r_petrous_ica_evt_2',
#   'r_cavernous_ica_evt_2',
#   'r_paraclinoid_ica_evt_2',
#   'r_ica_terminous_evt_2',
#   'r_prox_m1_evt_2',
#   'r_distal_m1_evt_2',
#   'r_prox_dom_m2_evt_2',
#   'r_prox_codom_m2_evt_2',
#   'r_prox_nondom_m2_evt_2',
#   'r_ant_temp_art_evt_2',
#   'r_dist_dom_m2_evt_2',
#   'r_dist_codom_m2_evt_2',
#   'r_dist_nondom_m2_evt_2',
#   'r_m3_evt_2',
#   'r_dist_m3_evt_2',
#   'r_prox_a1_evt_2',
#   'r_distal_a1_evt_2',
#   'r_prox_a2_evt_2',
#   'r_distal_a2_evt_2',
#   'r_pericallosal_evt_2',
#   'r_callosomarginal_evt_2',
#   'r_distal_aca_evt_2',
#   'r_vert_art_evt_2',
#   'r_vert_bas_jun_evt_2',
#   'r_mid_bas_evt_2',
#   'r_top_bas_evt_2',
#   'r_p1_evt_2',
#   'r_p2_evt_2',
#   'r_p3_evt_2',
#   'r_dist_pca_evt_2',
#   'r_aica_evt_2',
#   'r_pica_evt_2',
#   'r_sca_evt_2',
#   'other_evt_2',
#   'q3016',
#   'l_com_car_evt_2',
#   'l_car_bif_evt_2',
#   'l_dist_ext_ica_evt_2',
#   'l_petrous_ica_evt_2',
#   'l_cavernous_ica_evt_2',
#   'l_paraclinoid_ica_evt_2',
#   'l_ica_terminous_evt_2',
#   'l_prox_m1_evt_2',
#   'l_distal_m1_evt_2',
#   'l_prox_dom_m2_evt_2',
#   'l_prox_codom_m2_evt_2',
#   'l_prox_nondom_m2_evt_2',
#   'l_ant_temp_art_evt_2',
#   'l_dist_dom_m2_evt_2',
#   'l_dist_codom_m2_evt_2',
#   'l_dist_nondom_m2_evt_2',
#   'l_m3_evt_2',
#   'l_dist_m3_evt_2',
#   'l_prox_a1_evt_2',
#   'l_distal_a1_evt_2',
#   'l_prox_a2_evt_2',
#   'l_distal_a2_evt_2',
#   'l_pericallosal_evt_2',
#   'l_callosomarginal_evt_2',
#   'l_distal_aca_evt_2',
#   'l_vert_art_evt_2',
#   'l_vert_bas_jun_evt_2',
#   'l_mid_bas_evt_2',
#   'l_top_bas_evt_2',
#   'l_p1_evt_2',
#   'l_p2_evt_2',
#   'l_p3_evt_2',
#   'l_dist_pca_evt_2',
#   'l_aica_evt_2',
#   'l_pica_evt_2',
#   'l_sca_evt_2',
#   'q3017',
#   'q3018',
#   'q3019',
#   'r_com_car_evt_3',
#   'r_car_bif_evt_3',
#   'r_dist_ext_ica_evt_3',
#   'r_petrous_ica_evt_3',
#   'r_cavernous_ica_evt_3',
#   'r_paraclinoid_ica_evt_3',
#   'r_ica_terminous_evt_3',
#   'r_prox_m1_evt_3',
#   'r_distal_m1_evt_3',
#   'r_prox_dom_m2_evt_3',
#   'r_prox_codom_m2_evt_3',
#   'r_prox_nondom_m2_evt_3',
#   'r_ant_temp_art_evt_3',
#   'r_dist_dom_m2_evt_3',
#   'r_dist_codom_m2_evt_3',
#   'r_dist_nondom_m2_evt_3',
#   'r_m3_evt_3',
#   'r_dist_m3_evt_3',
#   'r_prox_a1_evt_3',
#   'r_distal_a1_evt_3',
#   'r_prox_a2_evt_3',
#   'r_distal_a2_evt_3',
#   'r_pericallosal_evt_3',
#   'r_callosomarginal_evt_3',
#   'r_distal_aca_evt_3',
#   'r_vert_art_evt_3',
#   'r_vert_bas_jun_evt_3',
#   'r_mid_bas_evt_3',
#   'r_top_bas_evt_3',
#   'r_p1_evt_3',
#   'r_p2_evt_3',
#   'r_p3_evt_3',
#   'r_dist_pca_evt_3',
#   'r_aica_evt_3',
#   'r_pica_evt_3',
#   'r_sca_evt_3',
#   'other_evt_3',
#   'q3020',
#   'l_com_car_evt_3',
#   'l_car_bif_evt_3',
#   'l_dist_ext_ica_evt_3',
#   'l_petrous_ica_evt_3',
#   'l_cavernous_ica_evt_3',
#   'l_paraclinoid_ica_evt_3',
#   'l_ica_terminous_evt_3',
#   'l_prox_m1_evt_3',
#   'l_distal_m1_evt_3',
#   'l_prox_dom_m2_evt_3',
#   'l_prox_codom_m2_evt_3',
#   'l_prox_nondom_m2_evt_3',
#   'l_ant_temp_art_evt_3',
#   'l_dist_dom_m2_evt_3',
#   'l_dist_codom_m2_evt_3',
#   'l_dist_nondom_m2_evt_3',
#   'l_m3_evt_3',
#   'l_dist_m3_evt_3',
#   'l_prox_a1_evt_3',
#   'l_distal_a1_evt_3',
#   'l_prox_a2_evt_3',
#   'l_distal_a2_evt_3',
#   'l_pericallosal_evt_3',
#   'l_callosomarginal_evt_3',
#   'l_distal_aca_evt_3',
#   'l_vert_art_evt_3',
#   'l_vert_bas_jun_evt_3',
#   'l_mid_bas_evt_3',
#   'l_top_bas_evt_3',
#   'l_p1_evt_3',
#   'l_p2_evt_3',
#   'l_p3_evt_3',
#   'l_dist_pca_evt_3',
#   'l_aica_evt_3',
#   'l_pica_evt_3',
#   'l_sca_evt_3',
#   'q3021',
#   'q3022',
#   'r_com_car_evt_4',
#   'r_car_bif_evt_4',
#   'r_dist_ext_ica_evt_4',
#   'r_petrous_ica_evt_4',
#   'r_cavernous_ica_evt_4',
#   'r_paraclinoid_ica_evt_4',
#   'r_ica_terminous_evt_4',
#   'r_prox_m1_evt_4',
#   'r_distal_m1_evt_4',
#   'r_prox_dom_m2_evt_4',
#   'r_prox_codom_m2_evt_4',
#   'r_prox_nondom_m2_evt_4',
#   'r_ant_temp_art_evt_4',
#   'r_dist_dom_m2_evt_4',
#   'r_dist_codom_m2_evt_4',
#   'r_dist_nondom_m2_evt_4',
#   'r_m3_evt_4',
#   'r_dist_m3_evt_4',
#   'r_prox_a1_evt_4',
#   'r_distal_a1_evt_4',
#   'r_prox_a2_evt_4',
#   'r_distal_a2_evt_4',
#   'r_pericallosal_evt_4',
#   'r_callosomarginal_evt_4',
#   'r_distal_aca_evt_4',
#   'r_vert_art_evt_4',
#   'r_vert_bas_jun_evt_4',
#   'r_mid_bas_evt_4',
#   'r_top_bas_evt_4',
#   'r_p1_evt_4',
#   'r_p2_evt_4',
#   'r_p3_evt_4',
#   'r_dist_pca_evt_4',
#   'r_aica_evt_4',
#   'r_pica_evt_4',
#   'r_sca_evt_4',
#   'other_evt_4',
#   'q3023',
#   'l_com_car_evt_4',
#   'l_car_bif_evt_4',
#   'l_dist_ext_ica_evt_4',
#   'l_petrous_ica_evt_4',
#   'l_cavernous_ica_evt_4',
#   'l_paraclinoid_ica_evt_4',
#   'l_ica_terminous_evt_4',
#   'l_prox_m1_evt_4',
#   'l_distal_m1_evt_4',
#   'l_prox_dom_m2_evt_4',
#   'l_prox_codom_m2_evt_4',
#   'l_prox_nondom_m2_evt_4',
#   'l_ant_temp_art_evt_4',
#   'l_dist_dom_m2_evt_4',
#   'l_dist_codom_m2_evt_4',
#   'l_dist_nondom_m2_evt_4',
#   'l_m3_evt_4',
#   'l_dist_m3_evt_4',
#   'l_prox_a1_evt_4',
#   'l_distal_a1_evt_4',
#   'l_prox_a2_evt_4',
#   'l_distal_a2_evt_4',
#   'l_pericallosal_evt_4',
#   'l_callosomarginal_evt_4',
#   'l_distal_aca_evt_4',
#   'l_vert_art_evt_4',
#   'l_vert_bas_jun_evt_4',
#   'l_mid_bas_evt_4',
#   'l_top_bas_evt_4',
#   'l_p1_evt_4',
#   'l_p2_evt_4',
#   'l_p3_evt_4',
#   'l_dist_pca_evt_4',
#   'l_aica_evt_4',
#   'l_pica_evt_4',
#   'l_sca_evt_4',
#   'q3024',
#   'q3025',
#   'r_com_car_evt_5',
#   'r_car_bif_evt_5',
#   'r_dist_ext_ica_evt_5',
#   'r_petrous_ica_evt_5',
#   'r_cavernous_ica_evt_5',
#   'r_paraclinoid_ica_evt_5',
#   'r_ica_terminous_evt_5',
#   'r_prox_m1_evt_5',
#   'r_distal_m1_evt_5',
#   'r_prox_dom_m2_evt_5',
#   'r_prox_codom_m2_evt_5',
#   'r_prox_nondom_m2_evt_5',
#   'r_ant_temp_art_evt_5',
#   'r_dist_dom_m2_evt_5',
#   'r_dist_codom_m2_evt_5',
#   'r_dist_nondom_m2_evt_5',
#   'r_m3_evt_5',
#   'r_dist_m3_evt_5',
#   'r_prox_a1_evt_5',
#   'r_distal_a1_evt_5',
#   'r_prox_a2_evt_5',
#   'r_distal_a2_evt_5',
#   'r_pericallosal_evt_5',
#   'r_callosomarginal_evt_5',
#   'r_distal_aca_evt_5',
#   'r_vert_art_evt_5',
#   'r_vert_bas_jun_evt_5',
#   'r_mid_bas_evt_5',
#   'r_top_bas_evt_5',
#   'r_p1_evt_5',
#   'r_p2_evt_5',
#   'r_p3_evt_5',
#   'r_dist_pca_evt_5',
#   'r_aica_evt_5',
#   'r_pica_evt_5',
#   'r_sca_evt_5',
#   'other_evt_5',
#   'q3026',
#   'l_com_car_evt_5',
#   'l_car_bif_evt_5',
#   'l_dist_ext_ica_evt_5',
#   'l_petrous_ica_evt_5',
#   'l_cavernous_ica_evt_5',
#   'l_paraclinoid_ica_evt_5',
#   'l_ica_terminous_evt_5',
#   'l_prox_m1_evt_5',
#   'l_distal_m1_evt_5',
#   'l_prox_dom_m2_evt_5',
#   'l_prox_codom_m2_evt_5',
#   'l_prox_nondom_m2_evt_5',
#   'l_ant_temp_art_evt_5',
#   'l_dist_dom_m2_evt_5',
#   'l_dist_codom_m2_evt_5',
#   'l_dist_nondom_m2_evt_5',
#   'l_m3_evt_5',
#   'l_dist_m3_evt_5',
#   'l_prox_a1_evt_5',
#   'l_distal_a1_evt_5',
#   'l_prox_a2_evt_5',
#   'l_distal_a2_evt_5',
#   'l_pericallosal_evt_5',
#   'l_callosomarginal_evt_5',
#   'l_distal_aca_evt_5',
#   'l_vert_art_evt_5',
#   'l_vert_bas_jun_evt_5',
#   'l_mid_bas_evt_5',
#   'l_top_bas_evt_5',
#   'l_p1_evt_5',
#   'l_p2_evt_5',
#   'l_p3_evt_5',
#   'l_dist_pca_evt_5',
#   'l_aica_evt_5',
#   'l_pica_evt_5',
#   'l_sca_evt_5',
#   'q3027',
#   'q3029',
#   'r_com_car_evt_6',
#   'r_car_bif_evt_6',
#   'r_dist_ext_ica_evt_6',
#   'r_petrous_ica_evt_6',
#   'r_cavernous_ica_evt_6',
#   'r_paraclinoid_ica_evt_6',
#   'r_ica_terminous_evt_6',
#   'r_prox_m1_evt_6',
#   'r_distal_m1_evt_6',
#   'r_prox_dom_m2_evt_6',
#   'r_prox_codom_m2_evt_6',
#   'r_prox_nondom_m2_evt_6',
#   'r_ant_temp_art_evt_6',
#   'r_dist_dom_m2_evt_6',
#   'r_dist_codom_m2_evt_6',
#   'r_dist_nondom_m2_evt_6',
#   'r_m3_evt_6',
#   'r_dist_m3_evt_6',
#   'r_prox_a1_evt_6',
#   'r_distal_a1_evt_6',
#   'r_prox_a2_evt_6',
#   'r_distal_a2_evt_6',
#   'r_pericallosal_evt_6',
#   'r_callosomarginal_evt_6',
#   'r_distal_aca_evt_6',
#   'r_vert_art_evt_6',
#   'r_vert_bas_jun_evt_6',
#   'r_mid_bas_evt_6',
#   'r_top_bas_evt_6',
#   'r_p1_evt_6',
#   'r_p2_evt_6',
#   'r_p3_evt_6',
#   'r_dist_pca_evt_6',
#   'r_aica_evt_6',
#   'r_pica_evt_6',
#   'r_sca_evt_6',
#   'other_evt_6',
#   'q3030',
#   'l_com_car_evt_6',
#   'l_car_bif_evt_6',
#   'l_dist_ext_ica_evt_6',
#   'l_petrous_ica_evt_6',
#   'l_cavernous_ica_evt_6',
#   'l_paraclinoid_ica_evt_6',
#   'l_ica_terminous_evt_6',
#   'l_prox_m1_evt_6',
#   'l_distal_m1_evt_6',
#   'l_prox_dom_m2_evt_6',
#   'l_prox_codom_m2_evt_6',
#   'l_prox_nondom_m2_evt_6',
#   'l_ant_temp_art_evt_6',
#   'l_dist_dom_m2_evt_6',
#   'l_dist_codom_m2_evt_6',
#   'l_dist_nondom_m2_evt_6',
#   'l_m3_evt_6',
#   'l_dist_m3_evt_6',
#   'l_prox_a1_evt_6',
#   'l_distal_a1_evt_6',
#   'l_prox_a2_evt_6',
#   'l_distal_a2_evt_6',
#   'l_pericallosal_evt_6',
#   'l_callosomarginal_evt_6',
#   'l_distal_aca_evt_6',
#   'l_vert_art_evt_6',
#   'l_vert_bas_jun_evt_6',
#   'l_mid_bas_evt_6',
#   'l_top_bas_evt_6',
#   'l_p1_evt_6',
#   'l_p2_evt_6',
#   'l_p3_evt_6',
#   'l_dist_pca_evt_6',
#   'l_aica_evt_6',
#   'l_pica_evt_6',
#   'l_sca_evt_6',
#   'q3031',
#   'q3032',
#   'q3034',
#   'r_com_car_evt_7',
#   'r_car_bif_evt_7',
#   'r_dist_ext_ica_evt_7',
#   'r_petrous_ica_evt_7',
#   'r_cavernous_ica_evt_7',
#   'r_paraclinoid_ica_evt_7',
#   'r_ica_terminous_evt_7',
#   'r_prox_m1_evt_7',
#   'r_distal_m1_evt_7',
#   'r_prox_dom_m2_evt_7',
#   'r_prox_codom_m2_evt_7',
#   'r_prox_nondom_m2_evt_7',
#   'r_ant_temp_art_evt_7',
#   'r_dist_dom_m2_evt_7',
#   'r_dist_codom_m2_evt_7',
#   'r_dist_nondom_m2_evt_7',
#   'r_m3_evt_7',
#   'r_dist_m3_evt_7',
#   'r_prox_a1_evt_7',
#   'r_distal_a1_evt_7',
#   'r_prox_a2_evt_7',
#   'r_distal_a2_evt_7',
#   'r_pericallosal_evt_7',
#   'r_callosomarginal_evt_7',
#   'r_distal_aca_evt_7',
#   'r_vert_art_evt_7',
#   'r_vert_bas_jun_evt_7',
#   'r_mid_bas_evt_7',
#   'r_top_bas_evt_7',
#   'r_p1_evt_7',
#   'r_p2_evt_7',
#   'r_p3_evt_7',
#   'r_dist_pca_evt_7',
#   'r_aica_evt_7',
#   'r_pica_evt_7',
#   'r_sca_evt_7',
#   'other_evt_7',
#   'q3035',
#   'l_com_car_evt_7',
#   'l_car_bif_evt_7',
#   'l_dist_ext_ica_evt_7',
#   'l_petrous_ica_evt_7',
#   'l_cavernous_ica_evt_7',
#   'l_paraclinoid_ica_evt_7',
#   'l_ica_terminous_evt_7',
#   'l_prox_m1_evt_7',
#   'l_distal_m1_evt_7',
#   'l_prox_dom_m2_evt_7',
#   'l_prox_codom_m2_evt_7',
#   'l_prox_nondom_m2_evt_7',
#   'l_ant_temp_art_evt_7',
#   'l_dist_dom_m2_evt_7',
#   'l_dist_codom_m2_evt_7',
#   'l_dist_nondom_m2_evt_7',
#   'l_m3_evt_7',
#   'l_dist_m3_evt_7',
#   'l_prox_a1_evt_7',
#   'l_distal_a1_evt_7',
#   'l_prox_a2_evt_7',
#   'l_distal_a2_evt_7',
#   'l_pericallosal_evt_7',
#   'l_callosomarginal_evt_7',
#   'l_distal_aca_evt_7',
#   'l_vert_art_evt_7',
#   'l_vert_bas_jun_evt_7',
#   'l_mid_bas_evt_7',
#   'l_top_bas_evt_7',
#   'l_p1_evt_7',
#   'l_p2_evt_7',
#   'l_p3_evt_7',
#   'l_dist_pca_evt_7',
#   'l_aica_evt_7',
#   'l_pica_evt_7',
#   'l_sca_evt_7',
#   'q3036',
#   'q3037',
#   'r_com_car_evt_8',
#   'r_car_bif_evt_8',
#   'r_dist_ext_ica_evt_8',
#   'r_petrous_ica_evt_8',
#   'r_cavernous_ica_evt_8',
#   'r_paraclinoid_ica_evt_8',
#   'r_ica_terminous_evt_8',
#   'r_prox_m1_evt_8',
#   'r_distal_m1_evt_8',
#   'r_prox_dom_m2_evt_8',
#   'r_prox_codom_m2_evt_8',
#   'r_prox_nondom_m2_evt_8',
#   'r_ant_temp_art_evt_8',
#   'r_dist_dom_m2_evt_8',
#   'r_dist_codom_m2_evt_8',
#   'r_dist_nondom_m2_evt_8',
#   'r_m3_evt_8',
#   'r_dist_m3_evt_8',
#   'r_prox_a1_evt_8',
#   'r_distal_a1_evt_8',
#   'r_prox_a2_evt_8',
#   'r_distal_a2_evt_8',
#   'r_pericallosal_evt_8',
#   'r_callosomarginal_evt_8',
#   'r_distal_aca_evt_8',
#   'r_vert_art_evt_8',
#   'r_vert_bas_jun_evt_8',
#   'r_mid_bas_evt_8',
#   'r_top_bas_evt_8',
#   'r_p1_evt_8',
#   'r_p2_evt_8',
#   'r_p3_evt_8',
#   'r_dist_pca_evt_8',
#   'r_aica_evt_8',
#   'r_pica_evt_8',
#   'r_sca_evt_8',
#   'other_evt_8',
#   'q3038',
#   'l_com_car_evt_8',
#   'l_car_bif_evt_8',
#   'l_dist_ext_ica_evt_8',
#   'l_petrous_ica_evt_8',
#   'l_cavernous_ica_evt_8',
#   'l_paraclinoid_ica_evt_8',
#   'l_ica_terminous_evt_8',
#   'l_prox_m1_evt_8',
#   'l_distal_m1_evt_8',
#   'l_prox_dom_m2_evt_8',
#   'l_prox_codom_m2_evt_8',
#   'l_prox_nondom_m2_evt_8',
#   'l_ant_temp_art_evt_8',
#   'l_dist_dom_m2_evt_8',
#   'l_dist_codom_m2_evt_8',
#   'l_dist_nondom_m2_evt_8',
#   'l_m3_evt_8',
#   'l_dist_m3_evt_8',
#   'l_prox_a1_evt_8',
#   'l_distal_a1_evt_8',
#   'l_prox_a2_evt_8',
#   'l_distal_a2_evt_8',
#   'l_pericallosal_evt_8',
#   'l_callosomarginal_evt_8',
#   'l_distal_aca_evt_8',
#   'l_vert_art_evt_8',
#   'l_vert_bas_jun_evt_8',
#   'l_mid_bas_evt_8',
#   'l_top_bas_evt_8',
#   'l_p1_evt_8',
#   'l_p2_evt_8',
#   'l_p3_evt_8',
#   'l_dist_pca_evt_8',
#   'l_aica_evt_8',
#   'l_pica_evt_8',
#   'l_sca_evt_8',
#   'q3039',
#   'q3040',
#   'r_com_car_evt_9',
#   'r_car_bif_evt_9',
#   'r_dist_ext_ica_evt_9',
#   'r_petrous_ica_evt_9',
#   'r_cavernous_ica_evt_9',
#   'r_paraclinoid_ica_evt_9',
#   'r_ica_terminous_evt_9',
#   'r_prox_m1_evt_9',
#   'r_distal_m1_evt_9',
#   'r_prox_dom_m2_evt_9',
#   'r_prox_codom_m2_evt_9',
#   'r_prox_nondom_m2_evt_9',
#   'r_ant_temp_art_evt_9',
#   'r_dist_dom_m2_evt_9',
#   'r_dist_codom_m2_evt_9',
#   'r_dist_nondom_m2_evt_9',
#   'r_m3_evt_9',
#   'r_dist_m3_evt_9',
#   'r_prox_a1_evt_9',
#   'r_distal_a1_evt_9',
#   'r_prox_a2_evt_9',
#   'r_distal_a2_evt_9',
#   'r_pericallosal_evt_9',
#   'r_callosomarginal_evt_9',
#   'r_distal_aca_evt_9',
#   'r_vert_art_evt_9',
#   'r_vert_bas_jun_evt_9',
#   'r_mid_bas_evt_9',
#   'r_top_bas_evt_9',
#   'r_p1_evt_9',
#   'r_p2_evt_9',
#   'r_p3_evt_9',
#   'r_dist_pca_evt_9',
#   'r_aica_evt_9',
#   'r_pica_evt_9',
#   'r_sca_evt_9',
#   'other_evt_9',
#   'q3041',
#   'l_com_car_evt_9',
#   'l_car_bif_evt_9',
#   'l_dist_ext_ica_evt_9',
#   'l_petrous_ica_evt_9',
#   'l_cavernous_ica_evt_9',
#   'l_paraclinoid_ica_evt_9',
#   'l_ica_terminous_evt_9',
#   'l_prox_m1_evt_9',
#   'l_distal_m1_evt_9',
#   'l_prox_dom_m2_evt_9',
#   'l_prox_codom_m2_evt_9',
#   'l_prox_nondom_m2_evt_9',
#   'l_ant_temp_art_evt_9',
#   'l_dist_dom_m2_evt_9',
#   'l_dist_codom_m2_evt_9',
#   'l_dist_nondom_m2_evt_9',
#   'l_m3_evt_9',
#   'l_dist_m3_evt_9',
#   'l_prox_a1_evt_9',
#   'l_distal_a1_evt_9',
#   'l_prox_a2_evt_9',
#   'l_distal_a2_evt_9',
#   'l_pericallosal_evt_9',
#   'l_callosomarginal_evt_9',
#   'l_distal_aca_evt_9',
#   'l_vert_art_evt_9',
#   'l_vert_bas_jun_evt_9',
#   'l_mid_bas_evt_9',
#   'l_top_bas_evt_9',
#   'l_p1_evt_9',
#   'l_p2_evt_9',
#   'l_p3_evt_9',
#   'l_dist_pca_evt_9',
#   'l_aica_evt_9',
#   'l_pica_evt_9',
#   'l_sca_evt_9',
#   'q3042',
#   'q3044',
#   'r_com_car_evt_10',
#   'r_car_bif_evt_10',
#   'r_dist_ext_ica_evt_10',
#   'r_petrous_ica_evt_10',
#   'r_cavernous_ica_evt_10',
#   'r_paraclinoid_ica_evt_10',
#   'r_ica_terminous_evt_10',
#   'r_prox_m1_evt_10',
#   'r_distal_m1_evt_10',
#   'r_prox_dom_m2_evt_10',
#   'r_prox_codom_m2_evt_10',
#   'r_prox_nondom_m2_evt_10',
#   'r_ant_temp_art_evt_10',
#   'r_dist_dom_m2_evt_10',
#   'r_dist_codom_m2_evt_10',
#   'r_dist_nondom_m2_evt_10',
#   'r_m3_evt_10',
#   'r_dist_m3_evt_10',
#   'r_prox_a1_evt_10',
#   'r_distal_a1_evt_10',
#   'r_prox_a2_evt_10',
#   'r_distal_a2_evt_10',
#   'r_pericallosal_evt_10',
#   'r_callosomarginal_evt_10',
#   'r_distal_aca_evt_10',
#   'r_vert_art_evt_10',
#   'r_vert_bas_jun_evt_10',
#   'r_mid_bas_evt_10',
#   'r_top_bas_evt_10',
#   'r_p1_evt_10',
#   'r_p2_evt_10',
#   'r_p3_evt_10',
#   'r_dist_pca_evt_10',
#   'r_aica_evt_10',
#   'r_pica_evt_10',
#   'r_sca_evt_10',
#   'other_evt_10',
#   'q3045',
#   'l_com_car_evt_10',
#   'l_car_bif_evt_10',
#   'l_dist_ext_ica_evt_10',
#   'l_petrous_ica_evt_10',
#   'l_cavernous_ica_evt_10',
#   'l_paraclinoid_ica_evt_10',
#   'l_ica_terminous_evt_10',
#   'l_prox_m1_evt_10',
#   'l_distal_m1_evt_10',
#   'l_prox_dom_m2_evt_10',
#   'l_prox_codom_m2_evt_10',
#   'l_prox_nondom_m2_evt_10',
#   'l_ant_temp_art_evt_10',
#   'l_dist_dom_m2_evt_10',
#   'l_dist_codom_m2_evt_10',
#   'l_dist_nondom_m2_evt_10',
#   'l_m3_evt_10',
#   'l_dist_m3_evt_10',
#   'l_prox_a1_evt_10',
#   'l_distal_a1_evt_10',
#   'l_prox_a2_evt_10',
#   'l_distal_a2_evt_10',
#   'l_pericallosal_evt_10',
#   'l_callosomarginal_evt_10',
#   'l_distal_aca_evt_10',
#   'l_vert_art_evt_10',
#   'l_vert_bas_jun_evt_10',
#   'l_mid_bas_evt_10',
#   'l_top_bas_evt_10',
#   'l_p1_evt_10',
#   'l_p2_evt_10',
#   'l_p3_evt_10',
#   'l_dist_pca_evt_10',
#   'l_aica_evt_10',
#   'l_pica_evt_10',
#   'l_sca_evt_10',
#   'q3046',
#   'q3047',
#   'q3048',
#   'q3049',
#   'r_com_car_evt_11',
#   'r_car_bif_evt_11',
#   'r_dist_ext_ica_evt_11',
#   'r_petrous_ica_evt_11',
#   'r_cavernous_ica_evt_11',
#   'r_paraclinoid_ica_evt_11',
#   'r_ica_terminous_evt_11',
#   'r_prox_m1_evt_11',
#   'r_distal_m1_evt_11',
#   'r_prox_dom_m2_evt_11',
#   'r_prox_codom_m2_evt_11',
#   'r_prox_nondom_m2_evt_11',
#   'r_ant_temp_art_evt_11',
#   'r_dist_dom_m2_evt_11',
#   'r_dist_codom_m2_evt_11',
#   'r_dist_nondom_m2_evt_11',
#   'r_m3_evt_11',
#   'r_dist_m3_evt_11',
#   'r_prox_a1_evt_11',
#   'r_distal_a1_evt_11',
#   'r_prox_a2_evt_11',
#   'r_distal_a2_evt_11',
#   'r_pericallosal_evt_11',
#   'r_callosomarginal_evt_11',
#   'r_distal_aca_evt_11',
#   'r_vert_art_evt_11',
#   'r_vert_bas_jun_evt_11',
#   'r_mid_bas_evt_11',
#   'r_top_bas_evt_11',
#   'r_p1_evt_11',
#   'r_p2_evt_11',
#   'r_p3_evt_11',
#   'r_dist_pca_evt_11',
#   'r_aica_evt_11',
#   'r_pica_evt_11',
#   'r_sca_evt_11',
#   'other_evt_11',
#   'q3050',
#   'l_com_car_evt_11',
#   'l_car_bif_evt_11',
#   'l_dist_ext_ica_evt_11',
#   'l_petrous_ica_evt_11',
#   'l_cavernous_ica_evt_11',
#   'l_paraclinoid_ica_evt_11',
#   'l_ica_terminous_evt_11',
#   'l_prox_m1_evt_11',
#   'l_distal_m1_evt_11',
#   'l_prox_dom_m2_evt_11',
#   'l_prox_codom_m2_evt_11',
#   'l_prox_nondom_m2_evt_11',
#   'l_ant_temp_art_evt_11',
#   'l_dist_dom_m2_evt_11',
#   'l_dist_codom_m2_evt_11',
#   'l_dist_nondom_m2_evt_11',
#   'l_m3_evt_11',
#   'l_dist_m3_evt_11',
#   'l_prox_a1_evt_11',
#   'l_distal_a1_evt_11',
#   'l_prox_a2_evt_11',
#   'l_distal_a2_evt_11',
#   'l_pericallosal_evt_11',
#   'l_callosomarginal_evt_11',
#   'l_distal_aca_evt_11',
#   'l_vert_art_evt_11',
#   'l_vert_bas_jun_evt_11',
#   'l_mid_bas_evt_11',
#   'l_top_bas_evt_11',
#   'l_p1_evt_11',
#   'l_p2_evt_11',
#   'l_p3_evt_11',
#   'l_dist_pca_evt_11',
#   'l_aica_evt_11',
#   'l_pica_evt_11',
#   'l_sca_evt_11',
#   'q3051',
#   'q3053',
#   'r_com_car_evt_12',
#   'r_car_bif_evt_12',
#   'r_dist_ext_ica_evt_12',
#   'r_petrous_ica_evt_12',
#   'r_cavernous_ica_evt_12',
#   'r_paraclinoid_ica_evt_12',
#   'r_ica_terminous_evt_12',
#   'r_prox_m1_evt_12',
#   'r_distal_m1_evt_12',
#   'r_prox_dom_m2_evt_12',
#   'r_prox_codom_m2_evt_12',
#   'r_prox_nondom_m2_evt_12',
#   'r_ant_temp_art_evt_12',
#   'r_dist_dom_m2_evt_12',
#   'r_dist_codom_m2_evt_12',
#   'r_dist_nondom_m2_evt_12',
#   'r_m3_evt_12',
#   'r_dist_m3_evt_12',
#   'r_prox_a1_evt_12',
#   'r_distal_a1_evt_12',
#   'r_prox_a2_evt_12',
#   'r_distal_a2_evt_12',
#   'r_pericallosal_evt_12',
#   'r_callosomarginal_evt_12',
#   'r_distal_aca_evt_12',
#   'r_vert_art_evt_12',
#   'r_vert_bas_jun_evt_12',
#   'r_mid_bas_evt_12',
#   'r_top_bas_evt_12',
#   'r_p1_evt_12',
#   'r_p2_evt_12',
#   'r_p3_evt_12',
#   'r_dist_pca_evt_12',
#   'r_aica_evt_12',
#   'r_pica_evt_12',
#   'r_sca_evt_12',
#   'other_evt_12',
#   'q3054',
#   'l_com_car_evt_12',
#   'l_car_bif_evt_12',
#   'l_dist_ext_ica_evt_12',
#   'l_petrous_ica_evt_12',
#   'l_cavernous_ica_evt_12',
#   'l_paraclinoid_ica_evt_12',
#   'l_ica_terminous_evt_12',
#   'l_prox_m1_evt_12',
#   'l_distal_m1_evt_12',
#   'l_prox_dom_m2_evt_12',
#   'l_prox_codom_m2_evt_12',
#   'l_prox_nondom_m2_evt_12',
#   'l_ant_temp_art_evt_12',
#   'l_dist_dom_m2_evt_12',
#   'l_dist_codom_m2_evt_12',
#   'l_dist_nondom_m2_evt_12',
#   'l_m3_evt_12',
#   'l_dist_m3_evt_12',
#   'l_prox_a1_evt_12',
#   'l_distal_a1_evt_12',
#   'l_prox_a2_evt_12',
#   'l_distal_a2_evt_12',
#   'l_pericallosal_evt_12',
#   'l_callosomarginal_evt_12',
#   'l_distal_aca_evt_12',
#   'l_vert_art_evt_12',
#   'l_vert_bas_jun_evt_12',
#   'l_mid_bas_evt_12',
#   'l_top_bas_evt_12',
#   'l_p1_evt_12',
#   'l_p2_evt_12',
#   'l_p3_evt_12',
#   'l_dist_pca_evt_12',
#   'l_aica_evt_12',
#   'l_pica_evt_12',
#   'l_sca_evt_12',
#   'q3055',
#   'q3056',
#   'q3058',
#   'r_com_car_evt_13',
#   'r_car_bif_evt_13',
#   'r_dist_ext_ica_evt_13',
#   'r_petrous_ica_evt_13',
#   'r_cavernous_ica_evt_13',
#   'r_paraclinoid_ica_evt_13',
#   'r_ica_terminous_evt_13',
#   'r_prox_m1_evt_13',
#   'r_distal_m1_evt_13',
#   'r_prox_dom_m2_evt_13',
#   'r_prox_codom_m2_evt_13',
#   'r_prox_nondom_m2_evt_13',
#   'r_ant_temp_art_evt_13',
#   'r_dist_dom_m2_evt_13',
#   'r_dist_codom_m2_evt_13',
#   'r_dist_nondom_m2_evt_13',
#   'r_m3_evt_13',
#   'r_dist_m3_evt_13',
#   'r_prox_a1_evt_13',
#   'r_distal_a1_evt_13',
#   'r_prox_a2_evt_13',
#   'r_distal_a2_evt_13',
#   'r_pericallosal_evt_13',
#   'r_callosomarginal_evt_13',
#   'r_distal_aca_evt_13',
#   'r_vert_art_evt_13',
#   'r_vert_bas_jun_evt_13',
#   'r_mid_bas_evt_13',
#   'r_top_bas_evt_13',
#   'r_p1_evt_13',
#   'r_p2_evt_13',
#   'r_p3_evt_13',
#   'r_dist_pca_evt_13',
#   'r_aica_evt_13',
#   'r_pica_evt_13',
#   'r_sca_evt_13',
#   'other_evt_13',
#   'q3059',
#   'l_com_car_evt_13',
#   'l_car_bif_evt_13',
#   'l_dist_ext_ica_evt_13',
#   'l_petrous_ica_evt_13',
#   'l_cavernous_ica_evt_13',
#   'l_paraclinoid_ica_evt_13',
#   'l_ica_terminous_evt_13',
#   'l_prox_m1_evt_13',
#   'l_distal_m1_evt_13',
#   'l_prox_dom_m2_evt_13',
#   'l_prox_codom_m2_evt_13',
#   'l_prox_nondom_m2_evt_13',
#   'l_ant_temp_art_evt_13',
#   'l_dist_dom_m2_evt_13',
#   'l_dist_codom_m2_evt_13',
#   'l_dist_nondom_m2_evt_13',
#   'l_m3_evt_13',
#   'l_dist_m3_evt_13',
#   'l_prox_a1_evt_13',
#   'l_distal_a1_evt_13',
#   'l_prox_a2_evt_13',
#   'l_distal_a2_evt_13',
#   'l_pericallosal_evt_13',
#   'l_callosomarginal_evt_13',
#   'l_distal_aca_evt_13',
#   'l_vert_art_evt_13',
#   'l_vert_bas_jun_evt_13',
#   'l_mid_bas_evt_13',
#   'l_top_bas_evt_13',
#   'l_p1_evt_13',
#   'l_p2_evt_13',
#   'l_p3_evt_13',
#   'l_dist_pca_evt_13',
#   'l_aica_evt_13',
#   ...],
#  'followup': ['q4001',
#   'q4002',
#   'q4003',
#   'q4004',
#   'ct_date_fu',
#   'ct_time_fu',
#   'cta_date_fu',
#   'cta_time_fu',
#   'ctp_date_fu',
#   'ctp_time_fu',
#   'mri_date_fu',
#   'mri_time_fu',
#   'mra_date_fu',
#   'mra_time_fu',
#   'mrp_date_fu',
#   'mrp_time_fu',
#   'aspects_score',
#   'cau_hea',
#   'len_nuc',
#   'ins_rib',
#   'int_cap',
#   'm1',
#   'm2',
#   'm3',
#   'm4',
#   'm5',
#   'm6',
#   'aspects_total',
#   'acu_hem_fu',
#   'acu_hem_loc',
#   'acu_hem_oth',
#   'f_u_cr_sign',
#   'comments',
#   'f_u_status',
#   'f_u_comments',
#   'f_u_init',
#   'followup_complete'],
#  'lab_use_only': ['ambra_img_url',
#   'is_test',
#   'is_phantom',
#   'lab_use_only_complete']}

# %%
field_instru_map
# Out:
# {'q1001': 'ct',
#  'q1002': 'ct',
#  'q1003': 'ct',
#  'q1004': 'ct',
#  'q1005': 'ct',
#  'q1006': 'ct',
#  'q1007': 'ct',
#  'q1008': 'ct',
#  'q7001': 'ct',
#  'q7002': 'ct',
#  'q7003': 'ct',
#  'q1009': 'ct',
#  'q1010': 'ct',
#  'q1011': 'ct',
#  'q1012_table': 'ct',
#  'q1012_raca': 'ct',
#  'q1012_r_heub': 'ct',
#  'q1012_rmca': 'ct',
#  'q1012_r_len_str': 'ct',
#  'q1012_r_ant_ch_art': 'ct',
#  'q1012_r_pca': 'ct',
#  'q1012_r_post_cer_art': 'ct',
#  'q1012_w_raca_rmca': 'ct',
#  'q1012_w_rmca_rpca': 'ct',
#  'q1012_w_raca_rpca': 'ct',
#  'q1012_laca': 'ct',
#  'q1012_l_heub': 'ct',
#  'q1012_l_mca': 'ct',
#  'q1012_l_len_str': 'ct',
#  'q1012_l_ant_ch_art': 'ct',
#  'q1012_l_pca': 'ct',
#  'q1012_l_post_cer_art': 'ct',
#  'q1012_w_laca_lmca': 'ct',
#  'q1012_w_lmca_lpca': 'ct',
#  'q1012_w_laca_lpca': 'ct',
#  'q1013_table': 'ct',
#  'q1013_r_pica': 'ct',
#  'q1013_r_aica': 'ct',
#  'q1013_r_sca': 'ct',
#  'q1013_r_pca_ct': 'ct',
#  'q1013_bas_per': 'ct',
#  'q1013_l_pica': 'ct',
#  'q1013_l_aica': 'ct',
#  'q1013_l_sca': 'ct',
#  'q1013_l_pca_ct': 'ct',
#  'q1015': 'ct',
#  'q1016': 'ct',
#  'hyperdense_table': 'ct',
#  'q1017_r_car_term': 'ct',
#  'q1017_r_mca': 'ct',
#  'q1017_bas': 'ct',
#  'q1017_r_aca_iv': 'ct',
#  'q1017_r_pca_iv': 'ct',
#  'q1017_other_box': 'ct',
#  'q1017_other': 'ct',
#  'q1017_l_car_term': 'ct',
#  'q1017_l_mca': 'ct',
#  'q1017_l_aca_iv': 'ct',
#  'q1017_l_pca_iv': 'ct',
#  'aspects_table': 'ct',
#  'q1019_cau': 'ct',
#  'q1020_len_nuc': 'ct',
#  'q1021_ins_rib': 'ct',
#  'q1022_int_cap': 'ct',
#  'q1023_m1': 'ct',
#  'q1024_m2': 'ct',
#  'q1025_m3': 'ct',
#  'q1026_m4': 'ct',
#  'q1027_m5': 'ct',
#  'q1028_m6': 'ct',
#  'q1029_total': 'ct',
#  'q1030': 'ct',
#  'q1031': 'ct',
#  'q1032': 'ct',
#  'q1033': 'ct',
#  'q1056': 'ct',
#  'q1034': 'ct',
#  'q1035': 'ct',
#  'q1036': 'ct',
#  'q1037': 'ct',
#  'q1038': 'ct',
#  'q1039': 'ct',
#  'q1040': 'ct',
#  'q1041': 'ct',
#  'q1042': 'ct',
#  'q1043': 'ct',
#  'q1044': 'ct',
#  'q1045': 'ct',
#  'q1046': 'ct',
#  'q1047': 'ct',
#  'q1048': 'ct',
#  'q1049': 'ct',
#  'q1050': 'ct',
#  'q1051': 'ct',
#  'q1052': 'ct',
#  'q1053': 'ct',
#  'q1054': 'ct',
#  'q1055': 'ct',
#  'q1057': 'ct',
#  'q1058': 'ct',
#  'q1059': 'ct',
#  'q1060': 'ct',
#  'pil_col_table': 'ct',
#  'q1061': 'ct',
#  'q1062': 'ct',
#  'q1063': 'ct',
#  'placeholder': 'ct',
#  'r_com_car_ct': 'ct',
#  'r_car_bif_ct': 'ct',
#  'r_dist_ext_ica_ct': 'ct',
#  'r_petrous_ica_ct': 'ct',
#  'r_cavernous_ica_ct': 'ct',
#  'r_paraclinoid_ica_ct': 'ct',
#  'r_ica_terminous_ct': 'ct',
#  'r_prox_m1_ct': 'ct',
#  'r_distal_m1_ct': 'ct',
#  'r_prox_dom_m2_ct': 'ct',
#  'r_prox_codom_m2_ct': 'ct',
#  'r_prox_nondom_m2_ct': 'ct',
#  'r_ant_temp_art_ct': 'ct',
#  'r_dist_dom_m2_ct': 'ct',
#  'r_dist_codom_m2_ct': 'ct',
#  'r_dist_nondom_m2_ct': 'ct',
#  'r_m3_ct': 'ct',
#  'r_dist_m3_ct': 'ct',
#  'r_prox_a1_ct': 'ct',
#  'r_distal_a1_ct': 'ct',
#  'r_prox_a2_ct': 'ct',
#  'r_distal_a2_ct': 'ct',
#  'r_pericallosal_ct': 'ct',
#  'r_callosomarginal_ct': 'ct',
#  'r_distal_aca_ct': 'ct',
#  'r_vert_art_ct': 'ct',
#  'r_vert_bas_jun_ct': 'ct',
#  'r_mid_bas_ct': 'ct',
#  'r_top_bas_ct': 'ct',
#  'r_p1_ct': 'ct',
#  'r_p2_ct': 'ct',
#  'r_p3_ct': 'ct',
#  'r_dist_pca_ct': 'ct',
#  'r_aica_ct': 'ct',
#  'r_pica_ct': 'ct',
#  'r_sca_ct': 'ct',
#  'other_ct': 'ct',
#  'l_com_car_ct': 'ct',
#  'l_car_bif_ct': 'ct',
#  'l_dist_ext_ica_ct': 'ct',
#  'l_petrous_ica_ct': 'ct',
#  'l_cavernous_ica_ct': 'ct',
#  'l_paraclinoid_ica_ct': 'ct',
#  'l_ica_terminous_ct': 'ct',
#  'l_prox_m1_ct': 'ct',
#  'l_distal_m1_ct': 'ct',
#  'l_prox_dom_m2_ct': 'ct',
#  'l_prox_codom_m2_ct': 'ct',
#  'l_prox_nondom_m2_ct': 'ct',
#  'l_ant_temp_art_ct': 'ct',
#  'l_dist_dom_m2_ct': 'ct',
#  'l_dist_codom_m2_ct': 'ct',
#  'l_dist_nondom_m2_ct': 'ct',
#  'l_m3_ct': 'ct',
#  'l_prox_a1_ct': 'ct',
#  'l_dist_m3_ct': 'ct',
#  'l_distal_a1_ct': 'ct',
#  'l_prox_a2_ct': 'ct',
#  'l_distal_a2_ct': 'ct',
#  'l_pericallosal_ct': 'ct',
#  'l_callosomarginal_ct': 'ct',
#  'l_distal_aca_ct': 'ct',
#  'l_vert_art_ct': 'ct',
#  'l_vert_bas_jun_ct': 'ct',
#  'l_mid_bas_ct': 'ct',
#  'l_top_bas_ct': 'ct',
#  'l_p1_ct': 'ct',
#  'l_p2_ct': 'ct',
#  'l_p3_ct': 'ct',
#  'l_dist_pca_ct': 'ct',
#  'l_aica_ct': 'ct',
#  'l_pica_ct': 'ct',
#  'l_sca_ct': 'ct',
#  'q1065': 'ct',
#  'q1087': 'ct',
#  'q1089': 'ct',
#  'q1091': 'ct',
#  'q1093': 'ct',
#  'q1094': 'ct',
#  'q1095': 'ct',
#  'q1097': 'ct',
#  'q1098': 'ct',
#  'q1099': 'ct',
#  'q1100': 'ct',
#  'ct_status': 'ct',
#  'ct_comments': 'ct',
#  'ct_init': 'ct',
#  'ct_complete': 'ct',
#  'q2001': 'mr',
#  'q2002': 'mr',
#  'q2003': 'mr',
#  'q2004': 'mr',
#  'q2005': 'mr',
#  'q2006': 'mr',
#  'q2007': 'mr',
#  'q2008': 'mr',
#  'q8001': 'mr',
#  'q8002': 'mr',
#  'q8003': 'mr',
#  'q2010': 'mr',
#  'q2011': 'mr',
#  'q2012': 'mr',
#  'q2013': 'mr',
#  'q2013_raca': 'mr',
#  'q2013_r_heub': 'mr',
#  'q2013_rmca': 'mr',
#  'q2013_r_len_str': 'mr',
#  'q2013_r_ant_ch_art': 'mr',
#  'q2013_r_pca': 'mr',
#  'q2013_w_raca_rmca': 'mr',
#  'q2013_w_rmca_rpca': 'mr',
#  'q2013_w_raca_rpca': 'mr',
#  'q2013_laca': 'mr',
#  'q2013_l_heub': 'mr',
#  'q2013_l_mca': 'mr',
#  'q2013_l_len_str': 'mr',
#  'q2013_l_ant_ch_art': 'mr',
#  'q2013_l_pca': 'mr',
#  'q2013_w_laca_lmca': 'mr',
#  'q2013_w_lmca_lpca': 'mr',
#  'q2013_w_laca_lpca': 'mr',
#  'q2014_table': 'mr',
#  'q2014_r_pica': 'mr',
#  'q2014_r_aica': 'mr',
#  'q2014_r_sca': 'mr',
#  'q2014_r_pca': 'mr',
#  'q2014_bas_per': 'mr',
#  'q2014_l_pica': 'mr',
#  'q2014_l_aica': 'mr',
#  'q2014_l_sca': 'mr',
#  'q2014_l_pca': 'mr',
#  'q2015': 'mr',
#  'q2016': 'mr',
#  'q2017': 'mr',
#  'q2018a': 'mr',
#  'q2019a': 'mr',
#  'q2019_r_par': 'mr',
#  'q2019_l_par': 'mr',
#  'q2019_r_occ': 'mr',
#  'q2019_l_occ': 'mr',
#  'q2019_r_tem': 'mr',
#  'q2019_l_tem': 'mr',
#  'q2019_r_fron': 'mr',
#  'q2019_l_fron': 'mr',
#  'q2019_r_ins': 'mr',
#  'q2019_l_ins': 'mr',
#  'q2019_r_cau_nuc': 'mr',
#  'q2019_l_cau_nuc': 'mr',
#  'q2019_r_put': 'mr',
#  'q2019_l_put': 'mr',
#  'q2019_r_cor': 'mr',
#  'q2019_l_cor': 'mr',
#  'q2019_r_int_cap': 'mr',
#  'q2019_l_int_cap': 'mr',
#  'q2019_r_thal': 'mr',
#  'q2019_l_thal': 'mr',
#  'q2019_r_cere': 'mr',
#  'q2019_l_cere': 'mr',
#  'q2019_r_pon': 'mr',
#  'q2019_l_pon': 'mr',
#  'q2019_r_midb': 'mr',
#  'q2019_l_midb': 'mr',
#  'q2019_r_med': 'mr',
#  'q2019_l_med': 'mr',
#  'q2019_r_oth_deep': 'mr',
#  'q2019_l_oth_deep': 'mr',
#  'q2019_r_mca_aca': 'mr',
#  'q2019_l_mca_aca': 'mr',
#  'q2019_r_pca_mca': 'mr',
#  'q2019_l_pca_mca': 'mr',
#  'q2019_r_pca_aca': 'mr',
#  'q2019_l_pca_aca': 'mr',
#  'q2019_r_scatt': 'mr',
#  'q2019_l_scatt': 'mr',
#  'q2019_oth': 'mr',
#  'q2020': 'mr',
#  'q2020_cau': 'mr',
#  'q2021_len_nuc': 'mr',
#  'q2022_ins_rib': 'mr',
#  'q2023_int_cap': 'mr',
#  'q2024_m1': 'mr',
#  'q2025_m2': 'mr',
#  'q2026_m3': 'mr',
#  'q2027_m4': 'mr',
#  'q2028_m5': 'mr',
#  'q2029_m6': 'mr',
#  'q2030_total': 'mr',
#  'q2018': 'mr',
#  'q2029_mr': 'mr',
#  'q2030_mr': 'mr',
#  'q2031_mr': 'mr',
#  'q2031_r_car_term_mr': 'mr',
#  'q2031_r_mca_mr': 'mr',
#  'q2031_r_aca_mr': 'mr',
#  'q2031_r_pca_mr': 'mr',
#  'q2031_l_car_term_mr': 'mr',
#  'q2031_l_mca_mr': 'mr',
#  'q2031_l_aca_mr': 'mr',
#  'q2031_l_pca_mr': 'mr',
#  'q2031_bas_mr': 'mr',
#  'q2031_oth_box': 'mr',
#  'q2032_mr': 'mr',
#  'q2033_mr': 'mr',
#  'q2034_mr': 'mr',
#  'q1035_mr': 'mr',
#  'q1036_mr': 'mr',
#  'q1037_mr': 'mr',
#  'q1038_mr': 'mr',
#  'q1039_mr': 'mr',
#  'q1040_mr': 'mr',
#  'q1041_mr': 'mr',
#  'microbleeds_table1': 'mr',
#  'q2045_d_r': 'mr',
#  'q2045_d_l': 'mr',
#  'q2045_p_r': 'mr',
#  'q2045_p_l': 'mr',
#  'q2046_d_r': 'mr',
#  'q2046_d_l': 'mr',
#  'q2046_p_r': 'mr',
#  'q2046_p_l': 'mr',
#  'q2047': 'mr',
#  'q2048_d_r': 'mr',
#  'q2048_d_l': 'mr',
#  'q2048_p_r': 'mr',
#  'q2048_p_l': 'mr',
#  'q2049_d_r': 'mr',
#  'q2049_d_l': 'mr',
#  'q2049_p_r': 'mr',
#  'q2049_p_l': 'mr',
#  'q2050_d_r': 'mr',
#  'q2050_d_l': 'mr',
#  'q2050_p_r': 'mr',
#  'q2050_p_l': 'mr',
#  'q2051_d_r': 'mr',
#  'q2051_d_l': 'mr',
#  'q2051_p_r': 'mr',
#  'q2051_p_l': 'mr',
#  'q2052_d_r': 'mr',
#  'q2052_d_l': 'mr',
#  'q2052_p_r': 'mr',
#  'q2052_p_l': 'mr',
#  'q2053_d_r': 'mr',
#  'q2053_d_l': 'mr',
#  'q2053_p_r': 'mr',
#  'q2053_p_l': 'mr',
#  'q2054': 'mr',
#  'q2055_d_r': 'mr',
#  'q2055_d_l': 'mr',
#  'q2055_p_r': 'mr',
#  'q2055_p_l': 'mr',
#  'q2056_d_r': 'mr',
#  'q2056_d_l': 'mr',
#  'q2056_p_r': 'mr',
#  'q2056_p_l': 'mr',
#  'q2057_d_r': 'mr',
#  'q2057_d_l': 'mr',
#  'q2057_p_r': 'mr',
#  'q2057_p_l': 'mr',
#  'q2058_d_r': 'mr',
#  'q2058_d_l': 'mr',
#  'q2058_p_r': 'mr',
#  'q2058_p_l': 'mr',
#  'q2059_d_r': 'mr',
#  'q2059_d_l': 'mr',
#  'q2059_p_r': 'mr',
#  'q2059_p_l': 'mr',
#  'q2060_l_t': 'mr',
#  'q2061_overall_t': 'mr',
#  'q2125': 'mr',
#  'q2126': 'mr',
#  'q2127': 'mr',
#  'q2062_mr': 'mr',
#  'q2063_mr': 'mr',
#  'q2064_mr': 'mr',
#  'q2065_mr': 'mr',
#  'q2062': 'mr',
#  'q2062_table': 'mr',
#  'q2063': 'mr',
#  'q2064': 'mr',
#  'q2065': 'mr',
#  'q2066': 'mr',
#  'q2067': 'mr',
#  'q2068': 'mr',
#  'q2068_table': 'mr',
#  'q2069': 'mr',
#  'q2070': 'mr',
#  'q2071': 'mr',
#  'q2072': 'mr',
#  'q2073': 'mr',
#  'q2074': 'mr',
#  'q2074_table': 'mr',
#  'q2075': 'mr',
#  'q2076': 'mr',
#  'q2077': 'mr',
#  'q2078': 'mr',
#  'q2079': 'mr',
#  'q2080': 'mr',
#  'q2080_table': 'mr',
#  'q2081': 'mr',
#  'q2082': 'mr',
#  'q2083': 'mr',
#  'q2084': 'mr',
#  'q2085': 'mr',
#  'q2086': 'mr',
#  'q2087': 'mr',
#  'q2088': 'mr',
#  'q2089': 'mr',
#  'q2090': 'mr',
#  'q2091': 'mr',
#  'q2092': 'mr',
#  'q2093': 'mr',
#  'q2094': 'mr',
#  'q2095': 'mr',
#  'q2096_table': 'mr',
#  'q2096': 'mr',
#  'q2097': 'mr',
#  'q2098': 'mr',
#  'q2099': 'mr',
#  'q2100': 'mr',
#  'pen_table': 'mr',
#  'q2101': 'mr',
#  'q2102': 'mr',
#  'q2103': 'mr',
#  'q2104': 'mr',
#  'q2105': 'mr',
#  'q2106': 'mr',
#  'q2107': 'mr',
#  'q2108': 'mr',
#  'q2109': 'mr',
#  'q2110': 'mr',
#  'q2111': 'mr',
#  'q2112_table': 'mr',
#  'q2112': 'mr',
#  'q2113': 'mr',
#  'q2114': 'mr',
#  'evt_table': 'mr',
#  'r_com_car_mr': 'mr',
#  'r_car_bif_mr': 'mr',
#  'r_dist_ext_ica_mr': 'mr',
#  'r_petrous_ica': 'mr',
#  'r_cavernous_ica': 'mr',
#  'r_paraclinoid_ica': 'mr',
#  'r_ica_terminous': 'mr',
#  'r_prox_m1': 'mr',
#  'r_distal_m1': 'mr',
#  'r_prox_dom_m2': 'mr',
#  'r_prox_codom_m2': 'mr',
#  'r_prox_nondom_m2': 'mr',
#  'r_ant_temp_art': 'mr',
#  'r_dist_dom_m2': 'mr',
#  'r_dist_codom_m2': 'mr',
#  'r_dist_nondom_m2': 'mr',
#  'r_m3': 'mr',
#  'r_dist_m3': 'mr',
#  'r_prox_a1': 'mr',
#  'r_distal_a1': 'mr',
#  'r_prox_a2': 'mr',
#  'r_distal_a2': 'mr',
#  'r_pericallosal': 'mr',
#  'r_callosomarginal': 'mr',
#  'r_distal_aca': 'mr',
#  'r_vert_art': 'mr',
#  'r_vert_bas_jun': 'mr',
#  'r_mid_bas': 'mr',
#  'r_top_bas': 'mr',
#  'r_p1': 'mr',
#  'r_p2': 'mr',
#  'r_p3': 'mr',
#  'r_dist_pca': 'mr',
#  'r_aica_mr': 'mr',
#  'r_pica_mr': 'mr',
#  'r_sca_mr': 'mr',
#  'other': 'mr',
#  'l_com_car_mr': 'mr',
#  'l_car_bif_mr': 'mr',
#  'l_dist_ext_ica_mr': 'mr',
#  'l_petrous_ica': 'mr',
#  'l_cavernous_ica': 'mr',
#  'l_paraclinoid_ica': 'mr',
#  'l_ica_terminous': 'mr',
#  'l_prox_m1': 'mr',
#  'l_distal_m1': 'mr',
#  'l_prox_dom_m2': 'mr',
#  'l_prox_codom_m2': 'mr',
#  'l_prox_nondom_m2': 'mr',
#  'l_ant_temp_art': 'mr',
#  'l_dist_dom_m2': 'mr',
#  'l_dist_codom_m2': 'mr',
#  'l_dist_nondom_m2': 'mr',
#  'l_m3': 'mr',
#  'l_dist_m3': 'mr',
#  'l_prox_a1': 'mr',
#  'l_distal_a1': 'mr',
#  'l_prox_a2': 'mr',
#  'l_distal_a2': 'mr',
#  'l_pericallosal': 'mr',
#  'l_callosomarginal': 'mr',
#  'l_distal_aca': 'mr',
#  'l_vert_art': 'mr',
#  'l_vert_bas_jun': 'mr',
#  'l_mid_bas': 'mr',
#  'l_top_bas': 'mr',
#  'l_p1': 'mr',
#  'l_p2': 'mr',
#  'l_p3': 'mr',
#  'l_dist_pca': 'mr',
#  'l_aica_mr': 'mr',
#  'l_pica_mr': 'mr',
#  'l_sca_mr': 'mr',
#  'q2115_oth': 'mr',
#  'q2117': 'mr',
#  'q2119': 'mr',
#  'q2121': 'mr',
#  'q2122': 'mr',
#  'q2124': 'mr',
#  'q2129': 'mr',
#  'q2131': 'mr',
#  'mr_status': 'mr',
#  'mri_comments': 'mr',
#  'mr_init': 'mr',
#  'mr_complete': 'mr',
#  'q3002': 'evt',
#  'q3003': 'evt',
#  'q3005': 'evt',
#  'q3006': 'evt',
#  'q3007': 'evt',
#  'q3008': 'evt',
#  'q3009': 'evt',
#  'q3010': 'evt',
#  'q3011': 'evt',
#  'prox_q3012': 'evt',
#  'q3012_first_cer_evt_table': 'evt',
#  'r_com_car_evt': 'evt',
#  'r_car_bif_evt': 'evt',
#  'r_dist_ext_ica_evt': 'evt',
#  'r_petrous_ica_evt': 'evt',
#  'r_cavernous_ica_evt': 'evt',
#  'r_paraclinoid_ica_evt': 'evt',
#  'r_ica_terminous_evt': 'evt',
#  'r_prox_m1_evt': 'evt',
#  'r_distal_m1_evt': 'evt',
#  'r_prox_dom_m2_evt': 'evt',
#  'r_prox_codom_m2_evt': 'evt',
#  'r_prox_nondom_m2_evt': 'evt',
#  'r_ant_temp_art_evt': 'evt',
#  'r_dist_dom_m2_evt': 'evt',
#  'r_dist_codom_m2_evt': 'evt',
#  'r_dist_nondom_m2_evt': 'evt',
#  'r_m3_evt': 'evt',
#  'r_dist_m3_evt': 'evt',
#  'r_prox_a1_evt': 'evt',
#  'r_distal_a1_evt': 'evt',
#  'r_prox_a2_evt': 'evt',
#  'r_distal_a2_evt': 'evt',
#  'r_pericallosal_evt': 'evt',
#  'r_callosomarginal_evt': 'evt',
#  'r_distal_aca_evt': 'evt',
#  'r_vert_art_evt': 'evt',
#  'r_vert_bas_jun_evt': 'evt',
#  'r_mid_bas_evt': 'evt',
#  'r_top_bas_evt': 'evt',
#  'r_p1_evt': 'evt',
#  'r_p2_evt': 'evt',
#  'r_p3_evt': 'evt',
#  'r_dist_pca_evt': 'evt',
#  'r_aica_evt': 'evt',
#  'r_pica_evt': 'evt',
#  'r_sca_evt': 'evt',
#  'other_evt': 'evt',
#  'l_com_car_evt': 'evt',
#  'l_car_bif_evt': 'evt',
#  'l_dist_ext_ica_evt': 'evt',
#  'l_petrous_ica_evt': 'evt',
#  'l_cavernous_ica_evt': 'evt',
#  'l_paraclinoid_ica_evt': 'evt',
#  'l_ica_terminous_evt': 'evt',
#  'l_prox_m1_evt': 'evt',
#  'l_distal_m1_evt': 'evt',
#  'l_prox_dom_m2_evt': 'evt',
#  'l_prox_codom_m2_evt': 'evt',
#  'l_prox_nondom_m2_evt': 'evt',
#  'l_ant_temp_art_evt': 'evt',
#  'l_dist_dom_m2_evt': 'evt',
#  'l_dist_codom_m2_evt': 'evt',
#  'l_dist_nondom_m2_evt': 'evt',
#  'l_m3_evt': 'evt',
#  'l_dist_m3_evt': 'evt',
#  'l_prox_a1_evt': 'evt',
#  'l_distal_a1_evt': 'evt',
#  'l_prox_a2_evt': 'evt',
#  'l_distal_a2_evt': 'evt',
#  'l_pericallosal_evt': 'evt',
#  'l_callosomarginal_evt': 'evt',
#  'l_distal_aca_evt': 'evt',
#  'l_vert_art_evt': 'evt',
#  'l_vert_bas_jun_evt': 'evt',
#  'l_mid_bas_evt': 'evt',
#  'l_top_bas_evt': 'evt',
#  'l_p1_evt': 'evt',
#  'l_p2_evt': 'evt',
#  'l_p3_evt': 'evt',
#  'l_dist_pca_evt': 'evt',
#  'l_aica_evt': 'evt',
#  'l_pica_evt': 'evt',
#  'l_sca_evt': 'evt',
#  'q3013': 'evt',
#  'q3014': 'evt',
#  'first_cer_bleed_table': 'evt',
#  'r_com_car_evt_2': 'evt',
#  'r_car_bif_evt_2': 'evt',
#  'r_dist_ext_ica_evt_2': 'evt',
#  'r_petrous_ica_evt_2': 'evt',
#  'r_cavernous_ica_evt_2': 'evt',
#  'r_paraclinoid_ica_evt_2': 'evt',
#  'r_ica_terminous_evt_2': 'evt',
#  'r_prox_m1_evt_2': 'evt',
#  'r_distal_m1_evt_2': 'evt',
#  'r_prox_dom_m2_evt_2': 'evt',
#  'r_prox_codom_m2_evt_2': 'evt',
#  'r_prox_nondom_m2_evt_2': 'evt',
#  'r_ant_temp_art_evt_2': 'evt',
#  'r_dist_dom_m2_evt_2': 'evt',
#  'r_dist_codom_m2_evt_2': 'evt',
#  'r_dist_nondom_m2_evt_2': 'evt',
#  'r_m3_evt_2': 'evt',
#  'r_dist_m3_evt_2': 'evt',
#  'r_prox_a1_evt_2': 'evt',
#  'r_distal_a1_evt_2': 'evt',
#  'r_prox_a2_evt_2': 'evt',
#  'r_distal_a2_evt_2': 'evt',
#  'r_pericallosal_evt_2': 'evt',
#  'r_callosomarginal_evt_2': 'evt',
#  'r_distal_aca_evt_2': 'evt',
#  'r_vert_art_evt_2': 'evt',
#  'r_vert_bas_jun_evt_2': 'evt',
#  'r_mid_bas_evt_2': 'evt',
#  'r_top_bas_evt_2': 'evt',
#  'r_p1_evt_2': 'evt',
#  'r_p2_evt_2': 'evt',
#  'r_p3_evt_2': 'evt',
#  'r_dist_pca_evt_2': 'evt',
#  'r_aica_evt_2': 'evt',
#  'r_pica_evt_2': 'evt',
#  'r_sca_evt_2': 'evt',
#  'other_evt_2': 'evt',
#  'q3016': 'evt',
#  'l_com_car_evt_2': 'evt',
#  'l_car_bif_evt_2': 'evt',
#  'l_dist_ext_ica_evt_2': 'evt',
#  'l_petrous_ica_evt_2': 'evt',
#  'l_cavernous_ica_evt_2': 'evt',
#  'l_paraclinoid_ica_evt_2': 'evt',
#  'l_ica_terminous_evt_2': 'evt',
#  'l_prox_m1_evt_2': 'evt',
#  'l_distal_m1_evt_2': 'evt',
#  'l_prox_dom_m2_evt_2': 'evt',
#  'l_prox_codom_m2_evt_2': 'evt',
#  'l_prox_nondom_m2_evt_2': 'evt',
#  'l_ant_temp_art_evt_2': 'evt',
#  'l_dist_dom_m2_evt_2': 'evt',
#  'l_dist_codom_m2_evt_2': 'evt',
#  'l_dist_nondom_m2_evt_2': 'evt',
#  'l_m3_evt_2': 'evt',
#  'l_dist_m3_evt_2': 'evt',
#  'l_prox_a1_evt_2': 'evt',
#  'l_distal_a1_evt_2': 'evt',
#  'l_prox_a2_evt_2': 'evt',
#  'l_distal_a2_evt_2': 'evt',
#  'l_pericallosal_evt_2': 'evt',
#  'l_callosomarginal_evt_2': 'evt',
#  'l_distal_aca_evt_2': 'evt',
#  'l_vert_art_evt_2': 'evt',
#  'l_vert_bas_jun_evt_2': 'evt',
#  'l_mid_bas_evt_2': 'evt',
#  'l_top_bas_evt_2': 'evt',
#  'l_p1_evt_2': 'evt',
#  'l_p2_evt_2': 'evt',
#  'l_p3_evt_2': 'evt',
#  'l_dist_pca_evt_2': 'evt',
#  'l_aica_evt_2': 'evt',
#  'l_pica_evt_2': 'evt',
#  'l_sca_evt_2': 'evt',
#  'q3017': 'evt',
#  'q3018': 'evt',
#  'q3019': 'evt',
#  'r_com_car_evt_3': 'evt',
#  'r_car_bif_evt_3': 'evt',
#  'r_dist_ext_ica_evt_3': 'evt',
#  'r_petrous_ica_evt_3': 'evt',
#  'r_cavernous_ica_evt_3': 'evt',
#  'r_paraclinoid_ica_evt_3': 'evt',
#  'r_ica_terminous_evt_3': 'evt',
#  'r_prox_m1_evt_3': 'evt',
#  'r_distal_m1_evt_3': 'evt',
#  'r_prox_dom_m2_evt_3': 'evt',
#  'r_prox_codom_m2_evt_3': 'evt',
#  'r_prox_nondom_m2_evt_3': 'evt',
#  'r_ant_temp_art_evt_3': 'evt',
#  'r_dist_dom_m2_evt_3': 'evt',
#  'r_dist_codom_m2_evt_3': 'evt',
#  'r_dist_nondom_m2_evt_3': 'evt',
#  'r_m3_evt_3': 'evt',
#  'r_dist_m3_evt_3': 'evt',
#  'r_prox_a1_evt_3': 'evt',
#  'r_distal_a1_evt_3': 'evt',
#  'r_prox_a2_evt_3': 'evt',
#  'r_distal_a2_evt_3': 'evt',
#  'r_pericallosal_evt_3': 'evt',
#  'r_callosomarginal_evt_3': 'evt',
#  'r_distal_aca_evt_3': 'evt',
#  'r_vert_art_evt_3': 'evt',
#  'r_vert_bas_jun_evt_3': 'evt',
#  'r_mid_bas_evt_3': 'evt',
#  'r_top_bas_evt_3': 'evt',
#  'r_p1_evt_3': 'evt',
#  'r_p2_evt_3': 'evt',
#  'r_p3_evt_3': 'evt',
#  'r_dist_pca_evt_3': 'evt',
#  'r_aica_evt_3': 'evt',
#  'r_pica_evt_3': 'evt',
#  'r_sca_evt_3': 'evt',
#  'other_evt_3': 'evt',
#  'q3020': 'evt',
#  'l_com_car_evt_3': 'evt',
#  'l_car_bif_evt_3': 'evt',
#  'l_dist_ext_ica_evt_3': 'evt',
#  'l_petrous_ica_evt_3': 'evt',
#  'l_cavernous_ica_evt_3': 'evt',
#  'l_paraclinoid_ica_evt_3': 'evt',
#  'l_ica_terminous_evt_3': 'evt',
#  'l_prox_m1_evt_3': 'evt',
#  'l_distal_m1_evt_3': 'evt',
#  'l_prox_dom_m2_evt_3': 'evt',
#  'l_prox_codom_m2_evt_3': 'evt',
#  'l_prox_nondom_m2_evt_3': 'evt',
#  'l_ant_temp_art_evt_3': 'evt',
#  'l_dist_dom_m2_evt_3': 'evt',
#  'l_dist_codom_m2_evt_3': 'evt',
#  'l_dist_nondom_m2_evt_3': 'evt',
#  'l_m3_evt_3': 'evt',
#  'l_dist_m3_evt_3': 'evt',
#  'l_prox_a1_evt_3': 'evt',
#  'l_distal_a1_evt_3': 'evt',
#  'l_prox_a2_evt_3': 'evt',
#  'l_distal_a2_evt_3': 'evt',
#  'l_pericallosal_evt_3': 'evt',
#  'l_callosomarginal_evt_3': 'evt',
#  'l_distal_aca_evt_3': 'evt',
#  'l_vert_art_evt_3': 'evt',
#  'l_vert_bas_jun_evt_3': 'evt',
#  'l_mid_bas_evt_3': 'evt',
#  'l_top_bas_evt_3': 'evt',
#  'l_p1_evt_3': 'evt',
#  'l_p2_evt_3': 'evt',
#  'l_p3_evt_3': 'evt',
#  'l_dist_pca_evt_3': 'evt',
#  'l_aica_evt_3': 'evt',
#  'l_pica_evt_3': 'evt',
#  'l_sca_evt_3': 'evt',
#  'q3021': 'evt',
#  'q3022': 'evt',
#  'r_com_car_evt_4': 'evt',
#  'r_car_bif_evt_4': 'evt',
#  'r_dist_ext_ica_evt_4': 'evt',
#  'r_petrous_ica_evt_4': 'evt',
#  'r_cavernous_ica_evt_4': 'evt',
#  'r_paraclinoid_ica_evt_4': 'evt',
#  'r_ica_terminous_evt_4': 'evt',
#  'r_prox_m1_evt_4': 'evt',
#  'r_distal_m1_evt_4': 'evt',
#  'r_prox_dom_m2_evt_4': 'evt',
#  'r_prox_codom_m2_evt_4': 'evt',
#  'r_prox_nondom_m2_evt_4': 'evt',
#  'r_ant_temp_art_evt_4': 'evt',
#  'r_dist_dom_m2_evt_4': 'evt',
#  'r_dist_codom_m2_evt_4': 'evt',
#  'r_dist_nondom_m2_evt_4': 'evt',
#  'r_m3_evt_4': 'evt',
#  'r_dist_m3_evt_4': 'evt',
#  'r_prox_a1_evt_4': 'evt',
#  'r_distal_a1_evt_4': 'evt',
#  'r_prox_a2_evt_4': 'evt',
#  'r_distal_a2_evt_4': 'evt',
#  'r_pericallosal_evt_4': 'evt',
#  'r_callosomarginal_evt_4': 'evt',
#  'r_distal_aca_evt_4': 'evt',
#  'r_vert_art_evt_4': 'evt',
#  'r_vert_bas_jun_evt_4': 'evt',
#  'r_mid_bas_evt_4': 'evt',
#  'r_top_bas_evt_4': 'evt',
#  'r_p1_evt_4': 'evt',
#  'r_p2_evt_4': 'evt',
#  'r_p3_evt_4': 'evt',
#  'r_dist_pca_evt_4': 'evt',
#  'r_aica_evt_4': 'evt',
#  'r_pica_evt_4': 'evt',
#  'r_sca_evt_4': 'evt',
#  'other_evt_4': 'evt',
#  'q3023': 'evt',
#  'l_com_car_evt_4': 'evt',
#  'l_car_bif_evt_4': 'evt',
#  'l_dist_ext_ica_evt_4': 'evt',
#  'l_petrous_ica_evt_4': 'evt',
#  'l_cavernous_ica_evt_4': 'evt',
#  'l_paraclinoid_ica_evt_4': 'evt',
#  'l_ica_terminous_evt_4': 'evt',
#  'l_prox_m1_evt_4': 'evt',
#  'l_distal_m1_evt_4': 'evt',
#  'l_prox_dom_m2_evt_4': 'evt',
#  'l_prox_codom_m2_evt_4': 'evt',
#  'l_prox_nondom_m2_evt_4': 'evt',
#  'l_ant_temp_art_evt_4': 'evt',
#  'l_dist_dom_m2_evt_4': 'evt',
#  'l_dist_codom_m2_evt_4': 'evt',
#  'l_dist_nondom_m2_evt_4': 'evt',
#  'l_m3_evt_4': 'evt',
#  'l_dist_m3_evt_4': 'evt',
#  'l_prox_a1_evt_4': 'evt',
#  'l_distal_a1_evt_4': 'evt',
#  'l_prox_a2_evt_4': 'evt',
#  'l_distal_a2_evt_4': 'evt',
#  'l_pericallosal_evt_4': 'evt',
#  'l_callosomarginal_evt_4': 'evt',
#  'l_distal_aca_evt_4': 'evt',
#  'l_vert_art_evt_4': 'evt',
#  'l_vert_bas_jun_evt_4': 'evt',
#  'l_mid_bas_evt_4': 'evt',
#  'l_top_bas_evt_4': 'evt',
#  'l_p1_evt_4': 'evt',
#  'l_p2_evt_4': 'evt',
#  'l_p3_evt_4': 'evt',
#  'l_dist_pca_evt_4': 'evt',
#  'l_aica_evt_4': 'evt',
#  'l_pica_evt_4': 'evt',
#  'l_sca_evt_4': 'evt',
#  'q3024': 'evt',
#  'q3025': 'evt',
#  'r_com_car_evt_5': 'evt',
#  'r_car_bif_evt_5': 'evt',
#  'r_dist_ext_ica_evt_5': 'evt',
#  'r_petrous_ica_evt_5': 'evt',
#  'r_cavernous_ica_evt_5': 'evt',
#  'r_paraclinoid_ica_evt_5': 'evt',
#  'r_ica_terminous_evt_5': 'evt',
#  'r_prox_m1_evt_5': 'evt',
#  'r_distal_m1_evt_5': 'evt',
#  'r_prox_dom_m2_evt_5': 'evt',
#  'r_prox_codom_m2_evt_5': 'evt',
#  'r_prox_nondom_m2_evt_5': 'evt',
#  'r_ant_temp_art_evt_5': 'evt',
#  'r_dist_dom_m2_evt_5': 'evt',
#  'r_dist_codom_m2_evt_5': 'evt',
#  'r_dist_nondom_m2_evt_5': 'evt',
#  'r_m3_evt_5': 'evt',
#  'r_dist_m3_evt_5': 'evt',
#  'r_prox_a1_evt_5': 'evt',
#  'r_distal_a1_evt_5': 'evt',
#  'r_prox_a2_evt_5': 'evt',
#  'r_distal_a2_evt_5': 'evt',
#  'r_pericallosal_evt_5': 'evt',
#  'r_callosomarginal_evt_5': 'evt',
#  'r_distal_aca_evt_5': 'evt',
#  'r_vert_art_evt_5': 'evt',
#  'r_vert_bas_jun_evt_5': 'evt',
#  'r_mid_bas_evt_5': 'evt',
#  'r_top_bas_evt_5': 'evt',
#  'r_p1_evt_5': 'evt',
#  'r_p2_evt_5': 'evt',
#  'r_p3_evt_5': 'evt',
#  'r_dist_pca_evt_5': 'evt',
#  'r_aica_evt_5': 'evt',
#  'r_pica_evt_5': 'evt',
#  'r_sca_evt_5': 'evt',
#  'other_evt_5': 'evt',
#  'q3026': 'evt',
#  'l_com_car_evt_5': 'evt',
#  'l_car_bif_evt_5': 'evt',
#  'l_dist_ext_ica_evt_5': 'evt',
#  'l_petrous_ica_evt_5': 'evt',
#  'l_cavernous_ica_evt_5': 'evt',
#  'l_paraclinoid_ica_evt_5': 'evt',
#  'l_ica_terminous_evt_5': 'evt',
#  'l_prox_m1_evt_5': 'evt',
#  'l_distal_m1_evt_5': 'evt',
#  'l_prox_dom_m2_evt_5': 'evt',
#  'l_prox_codom_m2_evt_5': 'evt',
#  'l_prox_nondom_m2_evt_5': 'evt',
#  'l_ant_temp_art_evt_5': 'evt',
#  'l_dist_dom_m2_evt_5': 'evt',
#  'l_dist_codom_m2_evt_5': 'evt',
#  'l_dist_nondom_m2_evt_5': 'evt',
#  'l_m3_evt_5': 'evt',
#  'l_dist_m3_evt_5': 'evt',
#  'l_prox_a1_evt_5': 'evt',
#  'l_distal_a1_evt_5': 'evt',
#  'l_prox_a2_evt_5': 'evt',
#  'l_distal_a2_evt_5': 'evt',
#  'l_pericallosal_evt_5': 'evt',
#  'l_callosomarginal_evt_5': 'evt',
#  'l_distal_aca_evt_5': 'evt',
#  'l_vert_art_evt_5': 'evt',
#  'l_vert_bas_jun_evt_5': 'evt',
#  'l_mid_bas_evt_5': 'evt',
#  'l_top_bas_evt_5': 'evt',
#  'l_p1_evt_5': 'evt',
#  'l_p2_evt_5': 'evt',
#  'l_p3_evt_5': 'evt',
#  'l_dist_pca_evt_5': 'evt',
#  'l_aica_evt_5': 'evt',
#  'l_pica_evt_5': 'evt',
#  'l_sca_evt_5': 'evt',
#  'q3027': 'evt',
#  'q3029': 'evt',
#  'r_com_car_evt_6': 'evt',
#  'r_car_bif_evt_6': 'evt',
#  'r_dist_ext_ica_evt_6': 'evt',
#  'r_petrous_ica_evt_6': 'evt',
#  'r_cavernous_ica_evt_6': 'evt',
#  'r_paraclinoid_ica_evt_6': 'evt',
#  'r_ica_terminous_evt_6': 'evt',
#  'r_prox_m1_evt_6': 'evt',
#  'r_distal_m1_evt_6': 'evt',
#  'r_prox_dom_m2_evt_6': 'evt',
#  'r_prox_codom_m2_evt_6': 'evt',
#  'r_prox_nondom_m2_evt_6': 'evt',
#  'r_ant_temp_art_evt_6': 'evt',
#  'r_dist_dom_m2_evt_6': 'evt',
#  'r_dist_codom_m2_evt_6': 'evt',
#  'r_dist_nondom_m2_evt_6': 'evt',
#  'r_m3_evt_6': 'evt',
#  'r_dist_m3_evt_6': 'evt',
#  'r_prox_a1_evt_6': 'evt',
#  'r_distal_a1_evt_6': 'evt',
#  'r_prox_a2_evt_6': 'evt',
#  'r_distal_a2_evt_6': 'evt',
#  'r_pericallosal_evt_6': 'evt',
#  'r_callosomarginal_evt_6': 'evt',
#  'r_distal_aca_evt_6': 'evt',
#  'r_vert_art_evt_6': 'evt',
#  'r_vert_bas_jun_evt_6': 'evt',
#  'r_mid_bas_evt_6': 'evt',
#  'r_top_bas_evt_6': 'evt',
#  'r_p1_evt_6': 'evt',
#  'r_p2_evt_6': 'evt',
#  'r_p3_evt_6': 'evt',
#  'r_dist_pca_evt_6': 'evt',
#  'r_aica_evt_6': 'evt',
#  'r_pica_evt_6': 'evt',
#  'r_sca_evt_6': 'evt',
#  'other_evt_6': 'evt',
#  'q3030': 'evt',
#  'l_com_car_evt_6': 'evt',
#  'l_car_bif_evt_6': 'evt',
#  'l_dist_ext_ica_evt_6': 'evt',
#  'l_petrous_ica_evt_6': 'evt',
#  'l_cavernous_ica_evt_6': 'evt',
#  'l_paraclinoid_ica_evt_6': 'evt',
#  'l_ica_terminous_evt_6': 'evt',
#  'l_prox_m1_evt_6': 'evt',
#  'l_distal_m1_evt_6': 'evt',
#  'l_prox_dom_m2_evt_6': 'evt',
#  'l_prox_codom_m2_evt_6': 'evt',
#  'l_prox_nondom_m2_evt_6': 'evt',
#  'l_ant_temp_art_evt_6': 'evt',
#  'l_dist_dom_m2_evt_6': 'evt',
#  'l_dist_codom_m2_evt_6': 'evt',
#  'l_dist_nondom_m2_evt_6': 'evt',
#  'l_m3_evt_6': 'evt',
#  'l_dist_m3_evt_6': 'evt',
#  'l_prox_a1_evt_6': 'evt',
#  'l_distal_a1_evt_6': 'evt',
#  'l_prox_a2_evt_6': 'evt',
#  'l_distal_a2_evt_6': 'evt',
#  'l_pericallosal_evt_6': 'evt',
#  'l_callosomarginal_evt_6': 'evt',
#  'l_distal_aca_evt_6': 'evt',
#  'l_vert_art_evt_6': 'evt',
#  'l_vert_bas_jun_evt_6': 'evt',
#  'l_mid_bas_evt_6': 'evt',
#  'l_top_bas_evt_6': 'evt',
#  'l_p1_evt_6': 'evt',
#  'l_p2_evt_6': 'evt',
#  'l_p3_evt_6': 'evt',
#  'l_dist_pca_evt_6': 'evt',
#  'l_aica_evt_6': 'evt',
#  'l_pica_evt_6': 'evt',
#  'l_sca_evt_6': 'evt',
#  'q3031': 'evt',
#  'q3032': 'evt',
#  'q3034': 'evt',
#  'r_com_car_evt_7': 'evt',
#  'r_car_bif_evt_7': 'evt',
#  'r_dist_ext_ica_evt_7': 'evt',
#  ...}

# %%
def map_project_to_db(project_records: pd.DataFrame, db_records: pd.DataFrame):
    '''
    Iterate through each project_records and check if
    that data is found in db_records
    '''

    logging.basicConfig(
        filename=f'redcap-db.log',
        filemode='w',
        level=logging.INFO
        )

    logger.info('===========================')
    for row in project_records.itertuples():
        patient_name = row.patient_name
        original_variable = row.redcap_variable
        redcap_variable = row.redcap_variable
        instance = row.instance
        crf_name = row.crf_name
        value = row.value

        # If the value is an int, it might be stored as a float in the project_records in df,
        # but an int in db_records. In this case, convert the float into the int.
        try:
            value = str(int(float(value)))
        except Exception:
            logger.info(f'Value {value} is not integer')


        # If the variable is a checkbox variable, then in project_records it would look like 
        # checkbox__1 but in db_records it is stored as checkbox(1). Convert it into 
        # the db convention for easier viewing.
        if check_checkbox_redcap_var(redcap_variable):
            master_variable = extract_variable(redcap_variable)
            before_choice = redcap_variable[:(redcap_variable.rindex('___'))]
            choice = redcap_variable[(redcap_variable.rindex('_') + 1):]
            redcap_variable = f'{before_choice}({choice})'

            # If the variable belongs to a non-filled out instrument, then skip.
            # project_records have values of variables belonging to unfilled instruments because
            # of them being having a default on REDCap. These values are not of concern.
                
            actual_crf = field_instru_map[master_variable]
            if not check_filled_instrument(patient_name, actual_crf, project_records):
                logging.info(f'Instrument {actual_crf} not filled for patient {patient_name}')
                continue
        else:
            actual_crf = field_instru_map[redcap_variable]
            if not check_filled_instrument(patient_name, actual_crf, project_records):
                logging.info(f'Instrument {actual_crf} not filled for patient {patient_name}')
                continue
        # Type of each relevant variable is printed out for
        # reference when comparison. For example, '1.0' != 1.0,
        # but for comparison purposes we treat these two as the same.
        logger.info(f'''
            ##########################
            #   Subject:     {patient_name}
            #   Instance:    {instance}
            #   OG Var:      {original_variable}
            $   Variable:    {redcap_variable}
            #   CRF_Name:    {crf_name}
            #   Value:       {value}
            ##########################
            ''')

        # If a repeating instrument
        if pd.notna(instance):
            logger.info('--------REPEATING')
            
            # If the variable is not actually in the repeating instrument, then skip
            if master_variable not in instru_field_map[crf_name]:
                logger.info(f'Master variable:    {master_variable}')
                logger.info(f'CRF:                {crf_name}')
                continue
            
            db_record = db_records[
                (db_records['patient_name'] == patient_name) &
                (db_records['redcap_variable'] == redcap_variable) &
                (db_records['instance'] == instance) &
                (db_records['crf_name'] == crf_name) &
                (db_records['value'] == value) &
                (db_records['deleted'] == 0) # Value must be not deleted in DB
            ]
            if len(db_record) == 0:
                potential_rows = db_records[
                    (db_records['patient_name'] == patient_name) &
                    (db_records['redcap_variable'] == redcap_variable) &
                    (db_records['crf_name'] == crf_name) 
                ]
                logger.info(
                    f'''
                    Not found in DB. Potential rows:

                    {potential_rows}
                    ''')
                return
            else:
                logger.info(f'Length of db_record: {len(db_record)}')
                logger.info('db_record:')
                logger.info(f'\n{db_record}')
        
        # If not a repeating instrument
        else:
            db_record = db_records[
                (db_records['patient_name'] == patient_name) &
                (db_records['redcap_variable'] == redcap_variable) &
                
                # Use .isna() instead of instance == instance because NaN != NaN is True.
                # https://stackoverflow.com/questions/10034149/why-is-nan-not-equal-to-nan
                
                (pd.isna(db_records['instance'])) & 
                (db_records['value'] == value) &
                (db_records['deleted'] == 0) # Value must be not deleted in DB
            ]
            if len(db_record) == 0:
                potential_rows = db_records[
                    (db_records['patient_name'] == patient_name) &
                    # (db_records['redcap_variable'] == redcap_variable) &
                    (pd.isna(db_records['instance']))
                ]

                logger.info(
                    f'''
                    Not found in DB. Potential rows:
                    
                    {potential_rows}
                    ''')
                return
            else:
                logger.info(f'Length of record found: {len(db_record)}')
                logger.info('db_record:')
                logger.info(f'\n{db_record}')

# %%
map_project_to_db(project_records, db_records)

# %%
tring = 'hel__hi'
# h  e  l   _    _   h   i
# 0  1  2   3    4   5   6

tring.rindex('__')
# Out:
# 3
